# %%
pip install datasketch
# Out:
# Requirement already satisfied: datasketch in c:\programdata\anaconda3\lib\site-packages (1.6.5)
# Requirement already satisfied: numpy>=1.11 in c:\programdata\anaconda3\lib\site-packages (from datasketch) (1.26.4)
# Requirement already satisfied: scipy>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from datasketch) (1.13.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from scripts.style_generation import get_style_genre
from scripts.first_n_words import get_first_n_words
from scripts.llm import ask_LLM
from scripts.kg_content import extract_kg_content
from scripts.minhash_vector import create_minhash_vector
from scripts.reconstruction_content import extract_reconstruction_content
from scripts.evaluate import evaluate_peformance
import scripts.prompts
import scripts.api_key

# %%
# Load the dataset from Hugging Face
dataset = pd.read_csv("data/ML-Arxiv-Papers.csv")
rows, columns = dataset.shape
# Extract the 'train' split
#train_dataset = dataset["train"]

# Create lists for titles and abstracts
# titles = [entry['title'] for entry in train_dataset]
# abstracts = [entry['abstract'] for entry in train_dataset]

# Create a list with concatenated title and abstract for each sample
concatenated_texts = dataset['abstract'] #[f"{title} {abstract}" for title, abstract in zip(titles, abstracts)]

API_KEY = "bc8ec9e53b89739f63f5e35cc60cfa152f25b24455dbb77e8cb7cf4860bbdfa6"


stop_len = 50000 #5000

model_name = "meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo"
#"meta-llama/Llama-3-70b-chat-hf"
#"NousResearch/Nous-Hermes-2-Mixtral-8x7B-DPO"
system_prompt = "You are a very smart very intelligence assistant who is very helpful."

all_kg_results = []
all_reconstruction_results = []
input_string_so_far_list = []



test = ask_LLM(model_name, "You are a very smart very intelligence assistant who is very helpful.", "Tell a joke aout knowledge graphs." , API_KEY, temperature=0.1, top_p=0.95, max_tokens=100,frequency_penalty=1.1, presence_penalty=1.1)

print(test)
# Out:
# Here's one:
#
# Why did the knowledge graph go to therapy?
#
# Because it was struggling to connect the dots!
#
# (get it? connecting the dots is a metaphor for building relationships between entities in a knowledge graph... ahh, I hope that one was enlightening!)

# %%
rows
# Out:
# 117592

# %%
def split_long_text(text, min_words=200, max_words=1000):
    """
    Splits a long text into segments of full sentences.
    
    Args:
    text (str): The input text to be split
    min_words (int): The minimum number of words per segment (default 200)
    max_words (int): The maximum number of words per segment (default 1000)
    
    Returns:
    list: A list of text segments
    """
    # Download necessary NLTK data (run once)
    nltk.download('punkt', quiet=True)
    
    # Tokenize the text into sentences
    sentences = sent_tokenize(text)
    
    segments = []
    current_segment = []
    current_word_count = 0
    
    for i, sentence in enumerate(sentences):
        sentence_words = word_tokenize(sentence)
        sentence_word_count = len(sentence_words)
        
        # If a single sentence exceeds max_words, split it
        if sentence_word_count > max_words:
            split_sentence = split_long_sentence(sentence, max_words)
            for sub_sentence in split_sentence:
                sub_word_count = len(word_tokenize(sub_sentence))
                
                if current_word_count + sub_word_count > max_words and current_word_count >= min_words:
                    segments.append(' '.join(current_segment))
                    current_segment = []
                    current_word_count = 0
                
                current_segment.append(sub_sentence)
                current_word_count += sub_word_count
        else:
            if current_word_count + sentence_word_count > max_words and current_word_count >= min_words:
                segments.append(' '.join(current_segment))
                current_segment = []
                current_word_count = 0
            
            current_segment.append(sentence)
            current_word_count += sentence_word_count
        
        # Check if there is a next sentence before accessing it
        if i < len(sentences) - 1:
            next_sentence_word_count = len(word_tokenize(sentences[i + 1]))
            if current_word_count >= min_words and next_sentence_word_count + current_word_count > max_words:
                segments.append(' '.join(current_segment))
                current_segment = []
                current_word_count = 0
    
    # Add any remaining sentences as the last segment
    if current_segment:
        segments.append(' '.join(current_segment))
    
    return segments

# %%
def concatenate_to_min_length(strings):
    result = []
    current_string = ""

    for s in strings:
        # If adding the current string doesn't make it 500 characters or more, keep adding
        if len(current_string) + len(s) < 500:
            current_string += s
        else:
            # If the current string is long enough, add it to the result and start a new string
            if current_string:
                result.append(current_string)
            current_string = s

        # If the current string is 500 characters or more, add it to the result and reset
        if len(current_string) >= 500:
            result.append(current_string)
            current_string = ""

    # Add the last string if it exists and isn't empty
    if current_string:
        result.append(current_string)

    return result

# Function to construct knowledge graphs and reconstruct text
def KG_construction_and_reconstruction(input_text, model, preprocessing_type="list_of_facts"):
    """
    This function takes an input text and a model, and performs the following steps:
    1. Determines the writing style of the input text
    2. Constructs a knowledge graph from the input text
    3. Reconstructs the text based on the knowledge graph
    
    Args:
    input_text (str): The input text to process
    model (str): The name of the language model to use

    Returns:
    tuple: Contains the input text, constructed knowledge graph, and reconstructed text
    """
    # Determine the writing style of the input text
    writing_style = get_style_genre(model_name, API_KEY, system_prompt ,get_first_n_words(  input_text, len(input_text) ) )

    if preprocessing_type=="paraphrasation":
      paraphrasation_list=[]
      chunks= split_long_text(input_text)
      for chunk in chunks:
        paraphrasation = ask_LLM(model_name, system_prompt, "Paraphrase the following text so that the resulting text consists entirely of short sentences of with less than 15 words per sentence and with simple grammar, while still using all important facts, contents, names, pharses, nouns and adjectives. BE VERY FACTUAL WHEN DOING THIS. The paraphrased text should still contain the same information (facts, nouns, verbs, adjectives, meaning, dates, numbers, names, places, variables, ...) as the INPUT TEXT, but with clean & easily understandable grammer. If there are broken tables, broken citations, gibberish or spam in the INPUT TEXT, just leave them out. Each sentence in PARAPHRASATION should end with either a dot (.) , a question mark (?) or an exklamation mark (!) and consist only of sentences that are shorter than 15 word. Do only output the PARAPHRASATION, nothing else. Even if the sentences are short, they should be very intelligent and very factual. INPUT TEXT:" +chunk + "\nPARAPHRASATION: ", API_KEY, temperature=0.5, top_p=0.95, max_tokens=1000,
                                                    frequency_penalty=1.0, presence_penalty=1.0)
        paraphrasation_list.append(paraphrasation)
        print(paraphrasation)
        
      # Initialize variables for knowledge graph construction
      sentences = sent_tokenize(" ".join(paraphrasation_list) )
      sentence_chunks= concatenate_to_min_length(sentences)
    
      print(sentence_chunks)
      print(len(sentence_chunks))

    if preprocessing_type=="list_of_facts":
      lists_of_facts_list=[]
      chunks= split_long_text(input_text)
      for chunk in chunks:
        paraphrasation = ask_LLM(model_name, system_prompt, "Write for the following text a list of ALL facts, events, actions, thoughts, ideas, quotes, ... in as VERY FACTUAL MANNER, that presents them on the point, so that it would be an ideal learning script to prepare for a question - answer exam about this text, without unnecessary fluff. Keep preserving all important facts, contents, names, pharses, nouns and adjectives. BE VERY FACTUAL WHEN DOING THIS. The resulting text should still contain the same information (facts, nouns, verbs, adjectives, meaning, dates, numbers, names, places, variables, ...) as the INPUT TEXT, but with clean & easily understandable grammer. If there are broken tables, broken citations, gibberish or spam in the INPUT TEXT, just leave them out. Each sentence in FACTS should end with either a dot (.) , a question mark (?) or an exklamation mark (!) and consist only of sentences that are shorter than 15 word. Do only output the FACTS, nothing else. Even if the sentences are short, they should be very intelligent and very factual. INPUT TEXT:" +chunk + "\nFACTS: ", API_KEY, temperature=0.5, top_p=0.95, max_tokens=1000,
                                                    frequency_penalty=1.0, presence_penalty=1.0)
        lists_of_facts_list.append(paraphrasation)
        print(paraphrasation)
        
      # Initialize variables for knowledge graph construction
      sentences = sent_tokenize(" ".join(lists_of_facts_list) )
      sentence_chunks= concatenate_to_min_length(sentences)
    
      print(sentence_chunks)
      print(len(sentence_chunks))


    current_kg = []
    current_kg.append("<style_analysis>" + writing_style + "</style_analysis>")
    segment_nr = 1
    reconstruction_so_far = ""
    input_string_so_far = ""
    print("<style_analysis>"+ writing_style + "</style_analysis>")
    # Process each sentence in the input text
    for sentence in sentence_chunks:
        
        input_string_so_far += sentence
        if len(input_string_so_far) > stop_len:
            break
        
        # Get the context for the current knowledge graph segment
        current_kg_context = current_kg[-50:] if len(current_kg) > 50 else current_kg
        current_kg_context = ' '.join(current_kg_context)

        # Generate the prompt for knowledge graph construction
        text = scripts.prompts.KG_format_example_prompt(current_kg_context, sentence)
        #print("Prompt:", text)

        
        # Generate the knowledge graph segment
        try:
            for i in range(2):
                knowledge_graph_segment = ask_LLM(model_name, system_prompt, text, API_KEY, temperature=0.5, top_p=0.95, max_tokens=1000,
                                                    frequency_penalty=1.1, presence_penalty=1.1)
                print("Constructed KG:")
                if not (extract_kg_content(knowledge_graph_segment) == None):
                    break
            
            # Add the knowledge graph segment to the current knowledge graph
            try:
                current_kg.append("<segment " + str(segment_nr) + ">\n" + extract_kg_content(
                        knowledge_graph_segment) + "<source_sentence_min_hash: " + str(
                        create_minhash_vector(sentence)) + " >\n" + "</segment " + str(segment_nr) + ">\n")
                print("<segment " + str(segment_nr) + ">\n" + extract_kg_content(
                        knowledge_graph_segment) + "<source_sentence_min_hash: " + str(
                        create_minhash_vector(sentence)) + " >\n" + "</segment " + str(segment_nr) + ">\n")
            except:
                current_kg.append(
                        "<segment " + str(segment_nr) + ">\n" + knowledge_graph_segment + "<source_sentence_min_hash: " + str(
                            create_minhash_vector(sentence)) + " >\n" + "</segment " + str(segment_nr) + ">\n")
                
                print("<segment " + str(segment_nr) + ">\n" + knowledge_graph_segment + "<source_sentence_min_hash: " + str(
                        create_minhash_vector(sentence)) + " >\n" + "</segment " + str(segment_nr) + ">\n")

            # Generate the prompt for text reconstruction
            prompt = scripts.prompts.KG_reconstruction_prompt(reconstruction_so_far, current_kg)
            
            # Reconstruct the text based on the knowledge graph
            for i in range(2):
                next_reconstruction = ask_LLM(model_name,
                                                "You are a very smart very intelligence assistant who is very helpful.",
                                                prompt, API_KEY, temperature=0.5, top_p=0.95, max_tokens=4000,
                                                frequency_penalty=1.1, presence_penalty=1.1)
                if not (extract_reconstruction_content(next_reconstruction) == None):
                    break

            reconstruction_so_far += extract_reconstruction_content(next_reconstruction)
            print("Recontructed Segment:", extract_reconstruction_content(next_reconstruction))
            segment_nr += 1

        except:
            print("No Kg found")
            
    return input_string_so_far, current_kg, reconstruction_so_far

# %%
def flatten_list_of_lists(list_of_lists):
    flattened_list = [item for sublist in list_of_lists for item in sublist]
    return ''.join(flattened_list)

# %%
input_string_so_far_list = []
all_kg_results = []
all_reconstruction_results = []

min_segment_length = 500  # in words

max_segment_length = 1000

count = 0
for input_text in concatenated_texts[0:1]:
    print(count)
    
    count = count+1
    print(len(input_text))
    split_text = split_long_text(input_text, min_segment_length, max_segment_length)
    
    #print(split_text[1])
    input_split_texts = []
    kg_for_input_split_texts = []
    KGs_so_far=""
    reconstruction_results_for_input_split_texts = []
    print(len(split_text) )
    
    for each_split_text in split_text[0:len(split_text)]:
        
        #print("Input segment:" ,each_split_text)

        input_string_list, kg_results, reconstruction_results = KG_construction_and_reconstruction(each_split_text, model_name)
        input_split_texts.append(input_string_list)
        kg_for_input_split_texts.append(kg_results)
        KGs_so_far= "\n".join(kg_for_input_split_texts)
        reconstruction_results_for_input_split_texts.append(reconstruction_results)
        
    input_string_so_far_list.append(flatten_list_of_lists(input_split_texts))
    all_kg_results.append(flatten_list_of_lists(kg_for_input_split_texts))
    all_reconstruction_results.append(flatten_list_of_lists(reconstruction_results_for_input_split_texts))
    
    #for i in range(0,len(split_text),1):
     #   input_string_so_far_list, all_kg_results, all_reconstruction_results = KG_construction_and_reconstruction(split_text[i], model_name)
    
    
    
    
#     if len(input_text)>1000:
#         pass
#     else:
#         input_string_so_far_list, all_kg_results, all_reconstruction_results = KG_construction_and_reconstruction(input_text, model_name)
# Out:
# 0
# 985
# 1
# Here are the facts extracted from the input text:
#
# The problem is to construct a predictor of a random variable $Y$ as a function of $X$.
# The predictor is constructed from an i.i.d. training sample from the joint distribution of $(X,Y)$.
# Allowable predictors are drawn from a specified class.
# The goal is to approach asymptotically the performance of the best predictor in the class.
# Perfect observation of the $X$-part of the sample is assumed.
# The $Y$-part of the sample is communicated at a finite bit rate.
# The encoding of the $Y$-values depends on the $X$-values.
# Regular conditions on the admissible predictors are assumed.
# Regular conditions on the underlying family of probability distributions are assumed.
# Regular conditions on the loss function are assumed.
# An information-theoretic characterization of achievable predictor performance is given.
# The characterization is in terms of conditional distortion-rate functions.
# The underlying family of probability distributions is a key factor.
# The loss function is a key factor.
# Nonparametric regression in Gaussian noise is an example.
# Gaussian noise is a type of noise.
# Nonparametric regression is a type of regression.
# The ideas are illustrated on the example of nonparametric regression.
# The example is in the context of Gaussian noise.
# The ultimate goal is to minimize distortion.
# The distortion is a function of the predictor and the data.
# The data is a random variable with a joint distribution.
# The joint distribution is a key factor in the problem.
# The problem is a statistical learning problem.
# Statistical learning is a type of machine learning.
# Machine learning is a field of study.
# The field of study is concerned with developing algorithms.
# Algorithms are used to make predictions.
# Predictions are made from data.
# Data is a key factor in machine learning.
# The data is used to train the predictor.
# The predictor is trained to minimize distortion.
# The distortion is minimized by choosing the best predictor.
# The best predictor is chosen from a specified class.
# The class of predictors is a key factor.
# The class of predictors is specified by the user.
# The user specifies the class of predictors.
# The class of predictors is a set of functions.
# Functions are used to make predictions.
# Predictions are made from the data.
# The data is a random variable.
# The random variable has a joint distribution.
# The joint distribution is a key factor.
# The joint distribution is a probability distribution.
# Probability distributions are used to model data.
# Data is modeled using probability distributions.
# Probability distributions are used to make predictions.
# Predictions are made from the data.
# The data is a random variable.
# The random variable has a joint distribution.
# The joint distribution is a key factor.
# The joint distribution is a probability distribution.
# The probability distribution is a Gaussian distribution.
# Gaussian distributions are used to model data.
# Data is modeled using Gaussian distributions.
# Gaussian distributions are used to make predictions.
# Predictions are made from the data.
# The data is a random variable.
# The random variable has a joint distribution.
# The joint distribution is a key factor.
# The joint distribution is a probability distribution.
# The probability distribution is a Gaussian distribution.
# The Gaussian distribution is a type of distribution.
# Distribution is a mathematical concept.
# Mathematical concepts are used to model data.
# Data is modeled using mathematical concepts.
# Mathematical concepts are used to make predictions.
# Predictions are made from the data.
# The data is a random variable.
# The random variable has a joint distribution.
# The joint distribution is a key factor.
# The joint distribution is a probability distribution.
# The probability distribution is a Gaussian distribution.
# The Gaussian distribution has a mean and variance.
# Mean and variance are used to model data.
# Data is modeled using mean and variance.
# Mean and variance are used to make predictions.
# Predictions are made from the data.
# The data is a random variable.
# The random variable has a joint distribution.
# The joint distribution is a key factor.
# The joint distribution is a probability distribution.
# The probability distribution is a Gaussian distribution.
# The Gaussian distribution has a mean and variance.
# The mean and variance are parameters.
# Parameters are used to model data.
# Data is modeled using parameters.
# Parameters are used to make predictions.
# Predictions are made from the data.
# The data is a random variable.
# The random variable has a joint distribution.
# The joint distribution is a key factor.
# The joint distribution is a probability distribution.
# The probability distribution is a Gaussian distribution.
# The Gaussian distribution has a mean and variance.
# The mean and variance are parameters.
# The parameters are estimated from the data.
# The data is used to estimate the parameters.
# The parameters are used to make predictions.
# Predictions are made from the data.
# The data is a random variable.
# The random variable has a joint distribution.
# The joint distribution is a key factor.
# The joint distribution is a probability distribution.
# The probability distribution is a Gaussian distribution.
# The Gaussian distribution has a mean and variance.
# The mean and variance are parameters.
# The parameters are estimated from the data.
# The data is used to estimate the parameters.
# The parameters
# ['Here are the facts extracted from the input text:\n\nThe problem is to construct a predictor of a random variable $Y$ as a function of $X$.The predictor is constructed from an i.i.d.training sample from the joint distribution of $(X,Y)$.Allowable predictors are drawn from a specified class.The goal is to approach asymptotically the performance of the best predictor in the class.Perfect observation of the $X$-part of the sample is assumed.', 'The $Y$-part of the sample is communicated at a finite bit rate.The encoding of the $Y$-values depends on the $X$-values.Regular conditions on the admissible predictors are assumed.Regular conditions on the underlying family of probability distributions are assumed.Regular conditions on the loss function are assumed.An information-theoretic characterization of achievable predictor performance is given.The characterization is in terms of conditional distortion-rate functions.', 'The underlying family of probability distributions is a key factor.The loss function is a key factor.Nonparametric regression in Gaussian noise is an example.Gaussian noise is a type of noise.Nonparametric regression is a type of regression.The ideas are illustrated on the example of nonparametric regression.The example is in the context of Gaussian noise.The ultimate goal is to minimize distortion.The distortion is a function of the predictor and the data.', 'The data is a random variable with a joint distribution.The joint distribution is a key factor in the problem.The problem is a statistical learning problem.Statistical learning is a type of machine learning.Machine learning is a field of study.The field of study is concerned with developing algorithms.Algorithms are used to make predictions.Predictions are made from data.Data is a key factor in machine learning.The data is used to train the predictor.', 'The predictor is trained to minimize distortion.The distortion is minimized by choosing the best predictor.The best predictor is chosen from a specified class.The class of predictors is a key factor.The class of predictors is specified by the user.The user specifies the class of predictors.The class of predictors is a set of functions.Functions are used to make predictions.Predictions are made from the data.The data is a random variable.The random variable has a joint distribution.', 'The joint distribution is a key factor.The joint distribution is a probability distribution.Probability distributions are used to model data.Data is modeled using probability distributions.Probability distributions are used to make predictions.Predictions are made from the data.The data is a random variable.The random variable has a joint distribution.The joint distribution is a key factor.The joint distribution is a probability distribution.', 'The probability distribution is a Gaussian distribution.Gaussian distributions are used to model data.Data is modeled using Gaussian distributions.Gaussian distributions are used to make predictions.Predictions are made from the data.The data is a random variable.The random variable has a joint distribution.The joint distribution is a key factor.The joint distribution is a probability distribution.The probability distribution is a Gaussian distribution.', 'The Gaussian distribution is a type of distribution.Distribution is a mathematical concept.Mathematical concepts are used to model data.Data is modeled using mathematical concepts.Mathematical concepts are used to make predictions.Predictions are made from the data.The data is a random variable.The random variable has a joint distribution.The joint distribution is a key factor.The joint distribution is a probability distribution.The probability distribution is a Gaussian distribution.', 'The Gaussian distribution has a mean and variance.Mean and variance are used to model data.Data is modeled using mean and variance.Mean and variance are used to make predictions.Predictions are made from the data.The data is a random variable.The rand ...
# 12
# <style_analysis>Here's a succinct yet thorough analysis of the text's writing style, rhythm, genre, and more:
#
# **Format and Genre:** The text is a technical article or research paper in the field of statistics and information theory, specifically within the sub-genre of machine learning and data compression.
#
# **Writing Style:** The text is formal, academic, and technical, utilizing complex syntactic structures, discipline-specific terminology (e.g., "i.i.d. training sample," "joint distribution," "conditional distortion-rate</style_analysis>
# Constructed KG:
# <segment 1>
#
#               'Predictor Construction Problem': {
#                   'relations': {
#                       'goal': 'Approach asymptotically the performance of the best predictor in the class',
#                       'assumption': 'Perfect observation of the X-part of the sample'
#                   },
#                   'attributes': {
#                       'description': 'Construct a predictor of a random variable Y as a function of X',
#                       'class_of_predictors': 'Specified class'
#                   }
#               },
#               'Joint Distribution of (X,Y)': {
#                   'relations': {
#                       'sample_used': 'i.i.d. training sample',
#                       'distribution_type': 'Joint distribution'
#                   },
#                   'attributes': {
#                       'type': 'Random variable',
#                       'components': ['X', 'Y']
#                   }
#               },
#               'i.i.d. Training Sample': {
#                   'relations': {
#                       'source': 'Joint Distribution of (X,Y)',
#                       'size': 'Unknown (Asymptotically infinite)'
#                   },
#                   'attributes': {
#                       'type': 'Random sample',
#                       'independence': 'Independent and identically distributed'
#                   }
#               },
#               'Best Predictor in the Class': {
#                   'relations': {
#                       'goal': 'Best possible performance',
#                       'class': 'Specified class of predictors'
#                   },
#                   'attributes': {
#                       'description': 'Optimal predictor in the given class'
#                   }
#               }
# <source_sentence_min_hash: [ 69847440  69645550 113505080 303289924 123507969   7829423  73340471
#   54847880   2709365  16169167  56884539  74243328 103865835 304926114
#  404779747  45231480] >
# </segment 1>
#
# Recontructed Segment:
#
# The goal of the predictor construction problem is to approach asymptotically the performance of the best predictor in the class, assuming perfect observation of the X-part of the sample. This problem involves constructing a predictor of a random variable Y as a function of X, where the class of predictors is specified.
#
# The joint distribution of (X, Y) is a fundamental concept in this problem, representing the joint probability distribution of the random variables X and Y. It is assumed that the joint distribution is based on an independent and identically distributed (i.i.d.) training sample, which is a random sample drawn from the joint distribution.
#
# The training sample is characterized as having an unknown size, which is asymptotically infinite. This means that the sample size is very large and can be considered infinite for the purposes of the analysis. The training sample is also assumed to be independent and identically distributed, meaning that each observation in the sample is independent of the others and has the same probability distribution.
#
# The best predictor in the class is the optimal predictor that achieves the best possible performance in the specified class of predictors. This predictor is the one that minimizes the error or maximizes the accuracy, depending on the specific performance metric used.
#
# In summary, the predictor construction problem involves constructing a predictor of Y based on X, assuming perfect observation of the X-part of the sample, and using an i.i.d. training sample to estimate the joint distribution of (X, Y). The goal is to approach asymptotically the performance of the best predictor in the class, which is the optimal predictor that achieves the best possible performance.
#
#
# Constructed KG:
# <segment 2>
#
#               'Conditional Distortion-Rate Function': {
#                   'relations': {
#                       'type': 'Information-theoretic characterization',
#                       'applies_to': 'Achievable predictor performance'
#                   },
#                   'attributes': {
#                       'description': 'Measure of predictor performance',
#                       'units': 'Bit per sample'
#                   }
#               },
#               'Achievable Predictor Performance': {
#                   'relations': {
#                       'characterized_by': 'Conditional distortion-rate function',
#                       'depends_on': 'Regular conditions on the loss function'
#                   },
#                   'attributes': {
#                       'description': 'Upper bound on predictor performance'
#                   }
#               },
#               'Regular Conditions on the Loss Function': {
#                   'relations': {
#                       'assumed': 'True',
#                       'applies_to': 'Predictor performance characterization'
#                   },
#                   'attributes': {
#                       'description': 'Constraints on the loss function'
#                   }
#               },
#               'Probability Distribution Family': {
#                   'relations': {
#                       'regular_conditions_assumed': 'True',
#                       'type': 'Underlying family of probability distributions'
#                   },
#                   'attributes': {
#                       'description': 'Set of probability distributions'
#                   }
#               },
#               'Predictor Performance Characterization': {
#                   'relations': {
#                       'type': 'Information-theoretic characterization',
#                       'applies_to': 'Achievable predictor performance'
#                   },
#                   'attributes': {
#                       'description': 'Measure of predictor performance'
#                   }
#               },
#               'Admissible Predictors': {
#                   'relations': {
#                       'regular_conditions_assumed': 'True',
#                       'type': 'Set of predictors'
#                   },
#                   'attributes': {
#                       'description': 'Set of predictors that meet the regular conditions'
#                   }
#               },
#               'Encoding of Y-values': {
#                   'relations': {
#                       'depends_on': 'X-values',
#                       'type': 'Encoding scheme'
#                   },
#                   'attributes': {
#                       'description': 'Method of encoding Y-values'
#                   }
#               },
#               'Bit Rate': {
#                   'relations': {
#                       'finite': 'True',
#                       'applies_to': 'Communication of Y-part of the sample'
#                   },
#                   'attributes': {
#                       'units': 'Bits per sample',
#                       'description': 'Rate at which Y-values are communicated'
#                   }
#               }
# <source_sentence_min_hash: [ 71718090  97085922    761466 247947095 133299020  47431596  61319759
#  306660385  47429823 437778517   9939647  74243328 184288807 307610120
#  116293349 203559980] >
# </segment 2>
#
# Recontructed Segment:
#
# The predictor construction problem involves constructing a predictor of a random variable Y as a function of X, where the class of predictors is specified. The goal is to approach asymptotically the performance of the best predictor in the class, assuming perfect observation of the X-part of the sample.
#
# The joint distribution of (X, Y) is a fundamental concept in this problem, representing the joint probability distribution of the random variables X and Y. It is assumed that the joint distribution is based on an independent and identically distributed (i.i.d.) training sample, which is a random sample drawn from the joint distribution.
#
# The training sample is characterized as having an unknown size, which is asymptotically infinite. This means that the sample size is very large and can be considered infinite for the purposes of the analysis. The training sample is also assumed to be independent and identically distributed, meaning that each observation in the sample is independent of the others and has the same probability distribution.
#
# The best predictor in the class is the optimal predictor that achieves the best possible performance in the specified class of predictors. This predictor is the one that minimizes the error or maximizes the accuracy, depending on the specific performance metric used.
#
# In addition to the joint distribution, the predictor construction problem also involves the concept of conditional distortion-rate function. This function measures the predictor performance and is characterized by the following relations:
#
# * Type: Information-theoretic characterization
# * Applies to: Achievable predictor performance
#
# The conditional distortion-rate function is a measure of predictor performance, expressed in units of bits per sample. It provides an upper bound on the achievable predictor performance, which is a key concept in the predictor construction problem.
#
# Furthermore, the predictor construction problem assumes regular conditions on the loss function. These conditions are constraints on the loss function that are assumed to be true, and they play a crucial role in the characterization of predictor performance. The regular conditions on the loss function are related to the probability distribution family, which is the set of probability distributions that the random variables X and Y belong to.
#
# The probability distribution family is an underlying family of probability distributions that is assumed to be regular. This means that the distribution is characterized by a set of parameters that are well-defined and can be estimated from the training sample. The regular conditions on the loss function are assumed to be true for this distribution family.
#
# In the context of predictor construction, the regular conditions on the loss function are used to define the set of admissible predictors. An admissible predictor is a predictor that meets the regular conditions on the loss function, and it is a key concept in the characterization of predictor performance.
#
# Finally, the predictor construction problem also involves the concept of encoding of Y-values. This is the method by which Y-values are encoded, and it is related to the bit rate, which is the rate at which Y-values are communicated. The bit rate is a finite quantity, expressed in units of bits per sample, and it is a key concept in the communication of Y-values.
#
# In summary, the predictor construction problem involves constructing a predictor of Y based on X, assuming perfect observation of the X-part of the sample, and using an i.i.d. training sample to estimate the joint distribution of (X, Y). The goal is to approach asymptotically the performance of the best predictor in the class, which is the optimal predictor that achieves the best possible performance.
#
# The predictor construction problem is characterized by several key concepts, including the conditional distortion-rate function, regular conditions on the loss function, probability distribution family, admissible predictors, encoding of Y-values, and bit rate. These concepts are related to each other and play a crucial role in the characterization of predictor performance.
#
#
# Constructed KG:
# <segment 3>
#
#               'Underlying Family of Probability Distributions': {
#                   'relations': {
#                       'key_factor': 'Predictor construction problem'
#                   },
#                   'attributes': {
#                       'description': 'Set of probability distributions',
#                       'type': 'Probability distribution family'
#                   }
#               },
#               'Loss Function': {
#                   'relations': {
#                       'key_factor': 'Predictor construction problem'
#                   },
#                   'attributes': {
#                       'description': 'Measure of error between predicted and actual values'
#                   }
#               },
#               'Nonparametric Regression': {
#                   'relations': {
#                       'example': 'Predictor construction problem',
#                       'type': 'Regression analysis'
#                   },
#                   'attributes': {
#                       'description': 'Regression model without assuming a specific distribution'
#                   }
#               },
#               'Gaussian Noise': {
#                   'relations': {
#                       'type': 'Noise model',
#                       'example': 'Nonparametric regression'
#                   },
#                   'attributes': {
#                       'description': 'Type of noise with a normal distribution'
#                   }
#               },
#               'Predictor Construction Problem': {
#                   'relations': {
#                       'goal': 'Minimize distortion',
#                       'example': 'Nonparametric regression'
#                   },
#                   'attributes': {
#                       'description': 'Problem of constructing a predictor from data'
#                   }
#               },
#               'Distortion': {
#                   'relations': {
#                       'function_of': 'Predictor and data',
#                       'type': 'Measure of error'
#                   },
#                   'attributes': {
#                       'description': 'Measure of difference between predicted and actual values'
#                   }
#               }
# <source_sentence_min_hash: [153168177  70740650  91521943  41423579  26156904 257628733 244751987
#   18993971  47429823 336774891  56884539  10285208 187731381 304926114
#  131699387 469236308] >
# </segment 3>
#
# Recontructed Segment:
#
# The predictor construction problem is a complex issue that involves constructing a predictor of a random variable Y based on the value of X, assuming perfect observation of the X-part of the sample. To approach this problem, it is essential to understand the underlying family of probability distributions, which is a set of probability distributions that the random variables X and Y belong to.
#
# The underlying family of probability distributions is a crucial concept in the predictor construction problem, as it provides a framework for understanding the relationships between the random variables X and Y. This family of distributions is characterized by a set of parameters that can be estimated from the training sample, and it is assumed to be regular, meaning that it meets certain conditions that are necessary for the predictor construction problem.
#
# One of the key concepts related to the underlying family of probability distributions is the loss function, which is a measure of the error between the predicted and actual values of Y. The loss function is a critical component of the predictor construction problem, as it provides a way to evaluate the performance of different predictors. In the context of the predictor construction problem, the loss function is assumed to meet certain regular conditions, which are constraints on the loss function that are necessary for the predictor construction problem.
#
# The regular conditions on the loss function are related to the probability distribution family and are used to define the set of admissible predictors. An admissible predictor is a predictor that meets the regular conditions on the loss function, and it is a key concept in the characterization of predictor performance. The set of admissible predictors is a critical component of the predictor construction problem, as it provides a way to evaluate the performance of different predictors.
#
# Another important concept related to the predictor construction problem is the encoding of Y-values, which is the method by which Y-values are encoded. The encoding of Y-values is related to the bit rate, which is the rate at which Y-values are communicated. The bit rate is a finite quantity, expressed in units of bits per sample, and it is a key concept in the communication of Y-values.
#
# In addition to the underlying family of probability distributions, loss function, and encoding of Y-values, the predictor construction problem also involves the concept of nonparametric regression, which is a type of regression analysis that does not assume a specific distribution of the data. Nonparametric regression is an example of a predictor construction problem, and it is used to estimate the relationship between the random variables X and Y.
#
# The predictor construction problem also involves the concept of Gaussian noise, which is a type of noise with a normal distribution. Gaussian noise is an example of a noise model that can be used in the predictor construction problem, and it is related to the nonparametric regression example.
#
# Finally, the predictor construction problem involves the concept of distortion, which is a measure of the error between the predicted and actual values of Y. Distortion is a critical component of the predictor construction problem, as it provides a way to evaluate the performance of different predictors. The distortion function is a measure of the difference between the predicted and actual values of Y, and it is related to the loss function.
#
# In summary, the predictor construction problem involves constructing a predictor of Y based on X, assuming perfect observation of the X-part of the sample, and using an i.i.d. training sample to estimate the joint distribution of (X, Y). The goal is to approach asymptotically the performance of the best predictor in the class, which is the optimal predictor that achieves the best possible performance.
#
#
# Constructed KG:
# <segment 4>
#
#               'Joint Distribution': {
#                   'relations': {
#                       'type': 'Probability distribution',
#                       'applies_to': 'Random variable'
#                   },
#                   'attributes': {
#                       'description': 'Joint probability distribution of a random variable',
#                       'type': 'Random variable'
#                   }
#               },
#               'Random Variable': {
#                   'relations': {
#                       'has_distributions': ['Joint Distribution'],
#                       'type': 'Variable with possible outcomes'
#                   },
#                   'attributes': {
#                       'description': 'Variable that can take on different values'
#                   }
#               },
#               'Statistical Learning Problem': {
#                   'relations': {
#                       'type': 'Problem type',
#                       'characterized_by': 'Joint distribution'
#                   },
#                   'attributes': {
#                       'description': 'Problem of making predictions from data'
#                   }
#               },
#               'Machine Learning': {
#                   'relations': {
#                       'sub_field': 'Statistical learning',
#                       'concerned_with': 'Algorithms for making predictions'
#                   },
#                   'attributes': {
#                       'description': 'Field of study that focuses on developing algorithms for making predictions'
#                   }
#               },
#               'Algorithms': {
#                   'relations': {
#                       'used_for': 'Making predictions',
#                       'developed_in': 'Machine learning'
#                   },
#                   'attributes': {
#                       'description': 'Sets of instructions for solving a problem'
#                   }
#               },
#               'Predictions': {
#                   'relations': {
#                       'made_from': 'Data',
#                       'type': 'Outcome of algorithm execution'
#                   },
#                   'attributes': {
#                       'description': 'Outcome of running an algorithm on data'
#                   }
#               },
#               'Data': {
#                   'relations': {
#                       'used_to_train': 'Predictor',
#                       'type': 'Input to algorithm'
#                   },
#                   'attributes': {
#                       'description': 'Input to an algorithm'
#                   }
#               },
#               'Predictor': {
#                   'relations': {
#                       'trained_on': 'Data',
#                       'type': 'Algorithm for making predictions'
#                   },
#                   'attributes': {
#                       'description': 'Algorithm for making predictions from data'
#                   }
#               }
# <source_sentence_min_hash: [297616339  69645550 113505080 219125346  82307762  17278764 133187408
#   22419451  35126058 206404860 508274232  74243328   3183692 279285265
#  224082839  45231480] >
# </segment 4>
#
# Recontructed Segment:
#
# The predictor construction problem involves constructing a predictor of a random variable Y based on the value of X, assuming perfect observation of the X-part of the sample. To approach this problem, it is essential to understand the underlying family of probability distributions, which is a set of probability distributions that the random variables X and Y belong to.
#
# The underlying family of probability distributions is a crucial concept in the predictor construction problem, as it provides a framework for understanding the relationships between the random variables X and Y. This family of distributions is characterized by a set of parameters that can be estimated from the training sample, and it is assumed to be regular, meaning that it meets certain conditions that are necessary for the predictor construction problem.
#
# One of the key concepts related to the underlying family of probability distributions is the joint distribution of (X, Y), which is a fundamental concept in this problem. The joint distribution represents the joint probability distribution of the random variables X and Y, and it is a measure of the relationship between the two variables.
#
# The joint distribution is a critical component of the predictor construction problem, as it provides a way to evaluate the performance of different predictors. In the context of the predictor construction problem, the joint distribution is assumed to be based on an independent and identically distributed (i.i.d.) training sample, which is a random sample drawn from the joint distribution.
#
# The training sample is characterized as having an unknown size, which is asymptotically infinite. This means that the sample size is very large and can be considered infinite for the purposes of the analysis. The training sample is also assumed to be independent and identically distributed, meaning that each observation in the sample is independent of the others and has the same probability distribution.
#
# In addition to the joint distribution, the predictor construction problem also involves the concept of conditional distortion-rate function. This function measures the predictor performance and is characterized by the following relations:
#
# * Type: Information-theoretic characterization
# * Applies to: Achievable predictor performance
#
# The conditional distortion-rate function is a measure of predictor performance, expressed in units of bits per sample. It provides an upper bound on the achievable predictor performance, which is a key concept in the predictor construction problem.
#
# The predictor construction problem also involves the concept of encoding of Y-values, which is the method by which Y-values are encoded. The encoding of Y-values is related to the bit rate, which is the rate at which Y-values are communicated. The bit rate is a finite quantity, expressed in units of bits per sample, and it is a key concept in the communication of Y-values.
#
# Furthermore, the predictor construction problem assumes regular conditions on the loss function. These conditions are constraints on the loss function that are assumed to be true, and they play a crucial role in the characterization of predictor performance. The regular conditions on the loss function are related to the probability distribution family, which is the set of probability distributions that the random variables X and Y belong to.
#
# The probability distribution family is an underlying family of probability distributions that is assumed to be regular. This means that the distribution is characterized by a set of parameters that are well-defined and can be estimated from the training sample. The regular conditions on the loss function are assumed to be true for this distribution family.
#
# In the context of predictor construction, the regular conditions on the loss function are used to define the set of admissible predictors. An admissible predictor is a predictor that meets the regular conditions on the loss function, and it is a key concept in the characterization of predictor performance.
#
# The predictor construction problem also involves the concept of nonparametric regression, which is a type of regression analysis that does not assume a specific distribution of the data. Nonparametric regression is an example of a predictor construction problem, and it is used to estimate the relationship between the random variables X and Y.
#
# In addition to the concepts mentioned above, the predictor construction problem also involves the concept of Gaussian noise, which is a type of noise with a normal distribution. Gaussian noise is an example of a noise model that can be used in the predictor construction problem, and it is related to the nonparametric regression example.
#
# Finally, the predictor construction problem involves the concept of distortion, which is a measure of the error between the predicted and actual values of Y. Distortion is a critical component of the predictor construction problem, as it provides a way to evaluate the performance of different predictors.
#
# In summary, the predictor construction problem involves constructing a predictor of Y based on X, assuming perfect observation of the X-part of the sample, and using an i.i.d. training sample to estimate the joint distribution of (X, Y). The goal is to approach asymptotically the performance of the best predictor in the class, which is the optimal predictor that achieves the best possible performance.
#
# The predictor construction problem is a complex issue that involves understanding the underlying family of probability distributions, the joint distribution, the conditional distortion-rate function, the encoding of Y-values, the regular conditions on the loss function, nonparametric regression, Gaussian noise, and distortion. These concepts are related to each other and play a crucial role in the characterization of predictor performance.
#
# The predictor construction problem is a fundamental concept in statistical learning and machine learning, and it is used to develop algorithms for making predictions from data. The goal of the predictor construction problem is to approach asymptotically the performance of the best predictor in the class, which is the optimal predictor that achieves the best possible performance.
#
# The predictor construction problem is characterized by several key concepts, including the joint distribution, the conditional distortion-rate function, the encoding of Y-values, the regular conditions on the loss function, nonparametric regression, Gaussian noise, and distortion. These concepts are related to each other and play a crucial role in the characterization of predictor performance.
#
# In the context of the predictor construction problem, the joint distribution is assumed to be based on an independent and identically distributed (i.i.d.) training sample, which is a random sample drawn from the joint distribution. The training sample is characterized as having an unknown size, which is asymptotically infinite. This means that the sample size is very large and can be considered infinite for the purposes of the analysis.
#
# The predictor construction problem also involves the concept of admissible predictors, which are predictors that meet the regular conditions on the loss function. An admissible predictor is a key concept in the characterization of predictor performance, and it provides a way to evaluate the performance of different predictors.
#
# In addition to the concepts mentioned above, the predictor construction problem also involves the concept of bit rate, which is the rate at which Y-values are communicated. The bit rate is a finite quantity, expressed in units of bits per sample, and it is a key concept in the communication of Y-values.
#
# The predictor construction problem is a fundamental concept in statistical learning and machine learning, and it is used to develop algorithms for making predictions from data. The goal of the predictor construction problem is to approach asymptotically the performance of the best predictor in the class, which is the optimal predictor that achieves the best possible performance.
#
#
# Constructed KG:
# <segment 5>
#
#               'Predictor Construction Problem': {
#                   'relations': {
#                       'goal': 'Minimize distortion',
#                       'assumes': 'Joint distribution of the data'
#                   },
#                   'attributes': {
#                       'description': 'Problem of constructing a predictor from data',
#                       'type': 'Predictor construction problem'
#                   }
#               },
#               'Distortion': {
#                   'relations': {
#                       'measured': 'Predictor and data',
#                       'type': 'Measure of error'
#                   },
#                   'attributes': {
#                       'description': 'Measure of difference between predicted and actual values'
#                   }
#               },
#               'Joint Distribution of the Data': {
#                   'relations': {
#                       'applies_to': 'Random variable',
#                       'type': 'Probability distribution'
#                   },
#                   'attributes': {
#                       'description': 'Joint probability distribution of the random variable',
#                       'type': 'Random variable'
#                   }
#               },
#               'Random Variable': {
#                   'relations': {
#                       'has_distribution': 'Joint Distribution of the Data'
#                   },
#                   'attributes': {
#                       'description': 'Variable that can take on different values'
#                   }
#               },
#               'Predictor': {
#                   'relations': {
#                       'trained_on': 'Data',
#                       'type': 'Algorithm for making predictions'
#                   },
#                   'attributes': {
#                       'description': 'Algorithm for making predictions from data'
#                   }
#               },
#               'Data': {
#                   'relations': {
#                       'used_to_train': 'Predictor',
#                       'type': 'Input to algorithm'
#                   },
#                   'attributes': {
#                       'description': 'Input to an algorithm'
#                   }
#               },
#               'Class of Predictors': {
#                   'relations': {
#                       'specified_by': 'User',
#                       'type': 'Set of functions'
#                   },
#                   'attributes': {
#                       'description': 'Set of functions for making predictions'
#                   }
#               },
#               'User': {
#                   'relations': {
#                       'specifies': 'Class of Predictors'
#                   },
#                   'attributes': {
#                       'description': 'Person who specifies the class of predictors'
#                   }
#               },
#               'Functions': {
#                   'relations': {
#                       'used_for': 'Making predictions',
#                       'type': 'Set of instructions'
#                   },
#                   'attributes': {
#                       'description': 'Sets of instructions for solving a problem'
#                   }
#               },
#               'Predictions': {
#                   'relations': {
#                       'made_from': 'Data',
#                       'type': 'Outcome of algorithm execution'
#                   },
#                   'attributes': {
#                       'description': 'Outcome of running an algorithm on data'
#                   }
#               },
#               'Algorithm': {
#                   'relations': {
#                       'used_for': 'Making predictions',
#                       'type': 'Set of instructions'
#                   },
#                   'attributes': {
#                       'description': 'Sets of instructions for solving a problem'
#                   }
#               }
# <source_sentence_min_hash: [153168177  69645550 113505080 131504505  26156904  53865188  13912681
#  306660385  80612661  90094578 158234511  74243328 272546140 170419165
#  131699387 268925531] >
# </segment 5>
#
# Recontructed Segment:
#
# The Predictor Construction Problem is a fundamental concept in statistical learning and machine learning, aiming to develop algorithms for making predictions from data. The goal is to approach asymptotically the performance of the best predictor in the class, which is the optimal predictor that achieves the best possible performance.
#
# The Predictor Construction Problem is characterized by several key concepts, including the Joint Distribution of the Data, which is a probability distribution that represents the joint probability of the random variables X and Y. This distribution is assumed to be based on an independent and identically distributed (i.i.d.) training sample, which is a random sample drawn from the joint distribution.
#
# The Joint Distribution of the Data is a critical component of the Predictor Construction Problem, as it provides a way to evaluate the performance of different predictors. The training sample is characterized as having an unknown size, which is asymptotically infinite. This means that the sample size is very large and can be considered infinite for the purposes of the analysis.
#
# Another key concept in the Predictor Construction Problem is the Distortion, which is a measure of the error between the predicted and actual values of Y. Distortion is a critical component of the predictor construction problem, as it provides a way to evaluate the performance of different predictors.
#
# The Predictor Construction Problem also involves the concept of Admissible Predictors, which are predictors that meet the regular conditions on the loss function. An admissible predictor is a key concept in the characterization of predictor performance, and it provides a way to evaluate the performance of different predictors.
#
# In addition to the concepts mentioned above, the Predictor Construction Problem also involves the concept of Bit Rate, which is the rate at which Y-values are communicated. The bit rate is a finite quantity, expressed in units of bits per sample, and it is a key concept in the communication of Y-values.
#
# The Predictor Construction Problem is a complex issue that involves understanding the underlying family of probability distributions, the joint distribution, the conditional distortion-rate function, the encoding of Y-values, the regular conditions on the loss function, nonparametric regression, Gaussian noise, and distortion. These concepts are related to each other and play a crucial role in the characterization of predictor performance.
#
# The Predictor Construction Problem is a fundamental concept in statistical learning and machine learning, and it is used to develop algorithms for making predictions from data. The goal of the Predictor Construction Problem is to approach asymptotically the performance of the best predictor in the class, which is the optimal predictor that achieves the best possible performance.
#
# The Predictor Construction Problem is characterized by several key concepts, including the Joint Distribution of the Data, the Distortion, the Admissible Predictors, the Bit Rate, and the underlying family of probability distributions. These concepts are related to each other and play a crucial role in the characterization of predictor performance.
#
# In the context of the Predictor Construction Problem, the Joint Distribution of the Data is assumed to be based on an independent and identically distributed (i.i.d.) training sample, which is a random sample drawn from the joint distribution. The training sample is characterized as having an unknown size, which is asymptotically infinite. This means that the sample size is very large and can be considered infinite for the purposes of the analysis.
#
# The Predictor Construction Problem also involves the concept of encoding of Y-values, which is the method by which Y-values are encoded. The encoding of Y-values is related to the bit rate, which is the rate at which Y-values are communicated. The bit rate is a finite quantity, expressed in units of bits per sample, and it is a key concept in the communication of Y-values.
#
# Furthermore, the Predictor Construction Problem assumes regular conditions on the loss function. These conditions are constraints on the loss function that are assumed to be true, and they play a crucial role in the characterization of predictor performance. The regular conditions on the loss function are related to the probability distribution family, which is the set of probability distributions that the random variables X and Y belong to.
#
# The probability distribution family is an underlying family of probability distributions that is assumed to be regular. This means that the distribution is characterized by a set of parameters that are well-defined and can be estimated from the training sample. The regular conditions on the loss function are assumed to be true, and they play a crucial role in the characterization of predictor performance.
#
# ...
#                       'type': 'Statistical concept'
#                   }
#               },
#               'Mean': {
#                   'relations': {
#                       'used_for': 'Gaussian Distribution',
#                       'type': 'Statistical measure'
#                   },
#                   'attributes': {
#                       'description': 'Average value of a set of data',
#                       'units': 'Value'
#                   }
#               },
#               'Variance': {
#                   'relations': {
#                       'used_for': 'Gaussian Distribution',
#                       'type': 'Statistical measure'
#                   },
#                   'attributes': {
#                       'description': 'Measure of spread or dispersion of a set of data',
#                       'units': 'Value^2'
#                   }
#               },
#               'Parameters': {
#                   'relations': {
#                       'used_for': 'Modeling data',
#                       'type': 'Variables used for modeling'
#                   },
#                   'attributes': {
#                       'description': 'Values used to describe a statistical model',
#                       'type': 'Variables used for modeling'
#                   }
#               }
# <source_sentence_min_hash: [153168177  52634355  91521943 311917730 136245013  53865188 133187408
#   18993971  35126058   1251650 202800569 436107976 272546140 161247681
#   37793319  45231480] >
# </segment 11>
#
# Recontructed Segment:
#
# The Predictor Construction Problem is a fundamental concept in statistical learning and machine learning, and it is used to develop algorithms for making predictions from data. The goal of the predictor construction problem is to approach asymptotically the performance of the best predictor in the class, which is the optimal predictor that achieves the best possible performance.
#
# The Parameters Estimation Problem is a related concept that involves estimating the parameters of a statistical model from data. This problem is essential in the predictor construction problem, as it provides the necessary information to construct a predictor from data.
#
# In the context of the predictor construction problem, the Data is used as input to the algorithm, and it is assumed to be available. The Data is used to estimate the parameters of the statistical model, which are then used to construct a predictor from the data.
#
# The Random Variable is a key concept in the predictor construction problem, and it has a distribution, which is typically modeled using a probability distribution, such as the Gaussian Distribution. The Joint Distribution of the Data is a critical component of the predictor construction problem, as it provides a way to evaluate the performance of different predictors.
#
# The Predictor Construction Problem involves constructing a predictor of a random variable Y based on the value of X, assuming perfect observation of the X-part of the sample, and using an i.i.d. training sample to estimate the joint distribution of (X, Y). The goal is to approach asymptotically the performance of the best predictor in the class, which is the optimal predictor that achieves the best possible performance.
#
# The Distortion is a measure of the error between the predicted and actual values of the Random Variable, and it is a critical component of the predictor construction problem. The distortion is measured as the difference between the predicted and actual values of the Random Variable.
#
# The Predictions are made from data using an algorithm, and the outcome of running an algorithm on data is a prediction of the Random Variable. The Algorithm is a set of instructions that is used to make predictions from data, and it is a key component of the predictor construction problem.
#
# The Gaussian Distribution is a fundamental concept in statistics and machine learning, used to model the uncertainty of random variables. It is characterized by a set of parameters, including the mean and variance, which describe the shape and spread of the distribution. In the context of the predictor construction problem, the Gaussian Distribution is used to model the joint distribution of the random variables X and Y.
#
# The Mean and Variance are two essential parameters of the Gaussian Distribution. The mean is the average value of a set of data, and it is used to describe the central tendency of the distribution. The variance, on the other hand, is a measure of the spread or dispersion of a set of data, and it is used to describe the variability of the distribution.
#
# The Parameters are used to describe a statistical model, and they are essential in the predictor construction problem. The Parameters are used to estimate the joint distribution of the data, which is then used to construct a predictor from the data.
#
# The Joint Distribution of the Data is a critical component of the predictor construction problem, as it provides a way to evaluate the performance of different predictors. The Joint Distribution of the Data is assumed to be based on an independent and identically distributed (i.i.d.) training sample, which is a random sample drawn from the joint distribution.
#
# The Predictor Construction Problem assumes that the joint distribution of the data is known, and it aims to minimize the distortion between the predicted and actual values of the Random Variable. The predictor construction problem is a complex issue that involves understanding the underlying family of probability distributions, the joint distribution, the conditional distortion-rate function, the encoding of Y-values, the regular conditions on the loss function, nonparametric regression, Gaussian noise, and distortion.
#
# These concepts are related to each other and play a crucial role in the characterization of predictor performance. The predictor construction problem is a fundamental concept in statistical learning and machine learning, and it is used to develop algorithms for making predictions from data.
#
# The goal of the predictor construction problem is to approach asymptotically the performance of the best predictor in the class, which is the optimal predictor that achieves the best possible performance. The predictor construction problem is characterized by several key concepts, including the joint distribution, the conditional distortion-rate function, the encoding of Y-values, the regular conditions on the loss function, nonparametric regression, Gaussian noise, and distortion.
#
# These concepts are related to each other and play a crucial role in the characterization of predictor performance. The predictor construction problem is a complex issue that involves understanding the underlying family of probability distributions, the joint distribution, the conditional distortion-rate function, the encoding of Y-values, the regular conditions on the loss function, nonparametric regression, Gaussian noise, and distortion.
#
# The predictor construction problem is a fundamental concept in statistical learning and machine learning, and it is used to develop algorithms for making predictions from data. The goal of the predictor construction problem is to approach asymptotically the performance of the best predictor in the class, which is the optimal predictor that achieves the best possible performance.
#
# In the context of the predictor construction problem, the joint distribution is assumed to be based on an independent and identically distributed (i.i.d.) training sample, which is a random sample drawn from the joint distribution. The training sample is characterized as having an unknown size, which is asymptotically infinite. This means that the sample size is very large and can be considered infinite for the purposes of the analysis.
#
# The predictor construction problem also involves the concept of nonparametric regression, which is a type of regression analysis that does not assume a specific distribution of the data. Nonparametric regression is an example of a predictor construction problem, and it is used to estimate the relationship between the random variables X and Y.
#
# In addition to the concepts mentioned above, the predictor construction problem also involves the concept of Gaussian noise, which is a type of noise with a normal distribution. Gaussian noise is an example of a noise model that can be used in the predictor construction problem, and it is related to the nonparametric regression example.
#
# Finally, the predictor construction problem involves the concept of distortion, which is a measure of the error between the predicted and actual values of Y. Distortion is a critical component of the predictor construction problem, as it provides a way to evaluate the performance of different predictors.
#
# In summary, the predictor construction problem involves constructing a predictor of a random variable Y based on the value of X, assuming perfect observation of the X-part of the sample, and using an i.i.d. training sample to estimate the joint distribution of (X, Y). The goal is to approach asymptotically the performance of the best predictor in the class, which is the optimal predictor that achieves the best possible performance.
#
#
# Constructed KG:
# <segment 12>
#
#               'Parameters Estimation Problem': {
#                   'relations': {
#                       'goal': 'Estimate parameters from data',
#                       'assumption': 'Data is available'
#                   },
#                   'attributes': {
#                       'description': 'Problem of estimating parameters from data',
#                       'type': 'Parameters estimation problem'
#                   }
#               },
#               'Data': {
#                   'relations': {
#                       'used_for': 'Estimating parameters',
#                       'type': 'Input to algorithm'
#                   },
#                   'attributes': {
#                       'description': 'Input to an algorithm',
#                       'type': 'Input to algorithm'
#                   }
#               },
#               'Parameters': {
#                   'relations': {
#                       'estimated_from': 'Data',
#                       'type': 'Values used for modeling'
#                   },
#                   'attributes': {
#                       'description': 'Values used to describe a statistical model',
#                       'type': 'Values used for modeling'
#                   }
#               }
# <source_sentence_min_hash: [190931820  52634355 113505080 311917730 136245013 497774472 138825044
#  399025842 249173004   1251650 454306225 664923769 272546140 161247681
#   37793319 278804245] >
# </segment 12>
#
# Recontructed Segment:
#
# The Parameters Estimation Problem is a crucial concept in statistical learning and machine learning, and it is used to develop algorithms for making predictions from data. The goal of the Parameters Estimation Problem is to estimate the parameters of a statistical model from data, which are then used to construct a predictor from the data.
#
# The Parameters Estimation Problem assumes that the data is available, and it is used as input to the algorithm. The data is used to estimate the parameters of the statistical model, which are then used to construct a predictor from the data. The parameters are values used to describe a statistical model, and they are essential in the predictor construction problem.
#
# The Joint Distribution of the Data is a critical component of the predictor construction problem, as it provides a way to evaluate the performance of different predictors. The Joint Distribution of the Data is assumed to be based on an independent and identically distributed (i.i.d.) training sample, which is a random sample drawn from the joint distribution.
#
# The Parameters Estimation Problem is related to the predictor construction problem, as it provides the necessary information to construct a predictor from data. The parameters are used to estimate the joint distribution of the data, which is then used to construct a predictor from the data.
#
# In the context of the Parameters Estimation Problem, the data is used as input to the algorithm, and it is assumed to be available. The data is used to estimate the parameters of the statistical model, which are then used to construct a predictor from the data. The parameters are values used to describe a statistical model, and they are essential in the predictor construction problem.
#
# The Parameters Estimation Problem involves estimating the parameters of a statistical model from data, which are then used to construct a predictor from the data. The goal of the Parameters Estimation Problem is to estimate the parameters accurately, which are then used to construct a predictor that achieves the best possible performance.
#
# The Parameters Estimation Problem is a complex issue that involves understanding the underlying family of probability distributions, the joint distribution, the conditional distortion-rate function, the encoding of Y-values, the regular conditions on the loss function, nonparametric regression, Gaussian noise, and distortion. These concepts are related to each other and play a crucial role in the characterization of predictor performance.
#
# The Parameters Estimation Problem is a fundamental concept in statistical learning and machine learning, and it is used to develop algorithms for making predictions from data. The goal of the Parameters Estimation Problem is to approach asymptotically the performance of the best predictor in the class, which is the optimal predictor that achieves the best possible performance.
#
# In the context of the Parameters Estimation Problem, the joint distribution is assumed to be based on an independent and identically distributed (i.i.d.) training sample, which is a random sample drawn from the joint distribution. The training sample is characterized as having an unknown size, which is asymptotically infinite. This means that the sample size is very large and can be considered infinite for the purposes of the analysis.
#
# The Parameters Estimation Problem also involves the concept of nonparametric regression, which is a type of regression analysis that does not assume a specific distribution of the data. Nonparametric regression is an example of a predictor construction problem, and it is used to estimate the relationship between the random variables X and Y.
#
# In addition to the concepts mentioned above, the Parameters Estimation Problem also involves the concept of Gaussian noise, which is a type of noise with a normal distribution. Gaussian noise is an example of a noise model that can be used in the predictor construction problem, and it is related to the nonparametric regression example.
#
# Finally, the Parameters Estimation Problem involves the concept of distortion, which is a measure of the error between the predicted and actual values of Y. Distortion is a critical component of the predictor construction problem, as it provides a way to evaluate the performance of different predictors.
#
# In summary, the Parameters Estimation Problem involves estimating the parameters of a statistical model from data, which are then used to construct a predictor from the data. The goal is to approach asymptotically the performance of the best predictor in the class, which is the optimal predictor that achieves the best possible performance.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 31
#      29     input_split_texts.append(input_string_list)
#      30     kg_for_input_split_texts.append(kg_results)
# ---> 31     KGs_so_far= "\n".join(kg_for_input_split_texts)
#      32     reconstruction_results_for_input_split_texts.append(reconstruction_results)
#      34 input_string_so_far_list.append(flatten_list_of_lists(input_split_texts))
#
# TypeError: sequence item 0: expected str instance, list found

# %%
input_string_so_far_list = []
all_kg_results = []
all_reconstruction_results = []

# Reading the entire contents of bible.txt into a single string
with open("""C:/Users/dlisg/Documents/BUD-E/bible.txt""", 'r', encoding='utf-8') as file:
    bible_text = file.read()

# Now, bible_text contains the entire contents of the file as a single string
print(bible_text[:1000])  # Print the first 1000 characters to verify



min_segment_length = 500  # in words

max_segment_length = 1000


count = 0
for input_text in [bible_text[:10000]]:
    print(count)
    
    count = count+1
    print(len(input_text))
    split_text = split_long_text(input_text, min_segment_length,max_segment_length)
    
    #print(split_text[1])
    input_split_texts = []
    kg_for_input_split_texts = []
    KGs_so_far=""
    reconstruction_results_for_input_split_texts = []
    
    for each_split_text in split_text[0:len(split_text)]:
        
        #print("Input segment:" ,each_split_text)

        input_string_list, kg_results, reconstruction_results = KG_construction_and_reconstruction(each_split_text, model_name)
        input_split_texts.append(input_string_list)
        kg_for_input_split_texts.append(kg_results)
        KGs_so_far= "\n".join(kg_for_input_split_texts)
        reconstruction_results_for_input_split_texts.append(reconstruction_results)
        
    input_string_so_far_list.append(flatten_list_of_lists(input_split_texts))
    all_kg_results.append(flatten_list_of_lists(kg_for_input_split_texts))
    all_reconstruction_results.append(flatten_list_of_lists(reconstruction_results_for_input_split_texts))
# Out:
# ﻿ERV
# English Revised Version
# Genesis 1:1	In the beginning God created the heaven and the earth.
# Genesis 1:2	And the earth was waste and void; and darkness was upon the face of the deep: and the spirit of God moved upon the face of the waters.
# Genesis 1:3	And God said, Let there be light: and there was light.
# Genesis 1:4	And God saw the light, that it was good: and God divided the light from the darkness.
# Genesis 1:5	And God called the light Day, and the darkness he called Night. And there was evening and there was morning, one day.
# Genesis 1:6	And God said, Let there be a firmament in the midst of the waters, and let it divide the waters from the waters.
# Genesis 1:7	And God made the firmament, and divided the waters which were under the firmament from the waters which were above the firmament: and it was so.
# Genesis 1:8	And God called the firmament Heaven. And there was evening and there was morning, a second day.
# Genesis 1:9	And God said, Let the waters under the heaven be gathered to
# 0
# 10000
# Here are the facts extracted from the text:
#
# 1. The English Revised Version (ERV) of the Bible contains the book of Genesis.
# 2. Genesis 1:1 states that God created the heaven and the earth.
# 3. The earth was waste and void, with darkness on its face, in Genesis 1:2.
# 4. The spirit of God moved upon the face of the waters in Genesis 1:2.
# 5. God said, "Let there be light," and there was light in Genesis 1:3.
# 6. God divided the light from the darkness in Genesis 1:4.
# 7. God called the light "Day" and the darkness "Night" in Genesis 1:5.
# 8. One day consisted of an evening and a morning in Genesis 1:5.
# 9. God said, "Let there be a firmament in the midst of the waters," in Genesis 1:6.
# 10. God made the firmament and divided the waters in Genesis 1:7.
# 11. God called the firmament "Heaven" in Genesis 1:8.
# 12. A second day consisted of an evening and a morning in Genesis 1:8.
# 13. God said, "Let the waters under the heaven be gathered together," in Genesis 1:9.
# 14. God created dry land and called it "Earth" in Genesis 1:10.
# 15. God called the gathering of the waters "Seas" in Genesis 1:10.
# 16. God saw that the creation was good in Genesis 1:10.
# 17. God said, "Let the earth put forth grass, herb, and fruit tree," in Genesis 1:11.
# 18. The earth brought forth grass, herb, and fruit tree in Genesis 1:12.
# 19. God saw that the creation was good in Genesis 1:12.
# 20. A third day consisted of an evening and a morning in Genesis 1:13.
# 21. God said, "Let there be lights in the firmament of the heaven," in Genesis 1:14.
# 22. God created lights to divide the day from the night in Genesis 1:14.
# 23. The lights were for signs, seasons, days, and years in Genesis 1:14.
# 24. God made the two great lights, the greater light and the lesser light, in Genesis 1:16.
# 25. The greater light ruled the day, and the lesser light ruled the night in Genesis 1:16.
# 26. God set the lights in the firmament of the heaven in Genesis 1:17.
# 27. A fourth day consisted of an evening and a morning in Genesis 1:19.
# 28. God said, "Let the waters bring forth the moving creature," in Genesis 1:20.
# 29. God created great sea-monsters and living creatures in Genesis 1:21.
# 30. God created winged fowl after their kinds in Genesis 1:21.
# 31. God saw that the creation was good in Genesis 1:21.
# 32. God blessed the living creatures in Genesis 1:22.
# 33. God said, "Be fruitful, and multiply, and fill the waters," in Genesis 1:22.
# 34. A fifth day consisted of an evening and a morning in Genesis 1:23.
# 35. God said, "Let the earth bring forth the living creature," in Genesis 1:24.
# 36. God created cattle, creeping things, and beasts of the earth in Genesis 1:25.
# 37. God saw that the creation was good in Genesis 1:25.
# 38. God said, "Let us make man in our image," in Genesis 1:26.
# 39. God created man in his own image in Genesis 1:27.
# 40. God created man and woman in Genesis 1:27.
# 41. God blessed man and woman in Genesis 1:28.
# 42. God said, "Be fruitful, and multiply, and replenish the earth," in Genesis 1:28.
# 43. God gave man dominion over the earth in Genesis 1:28.
# 44. God said, "Behold, I have given you every herb yielding seed," in Genesis 1:29.
# 45. God gave man every green herb for meat in Genesis 1:30.
# 46. God gave every beast of the earth, every fowl of the air, and every living thing green herbs for meat in Genesis 1:30.
# 47. God saw that everything he had made was very good in Genesis 1:31.
# 48. A sixth day consisted of an evening and a morning in Genesis 1:31.
# ['Here are the facts extracted from the text:\n\n1.The English Revised Version (ERV) of the Bible contains the book of Genesis.2.Genesis 1:1 states that God created the heaven and the earth.3.The earth was waste and void, with darkness on its face, in Genesis 1:2.4.The spirit of God moved upon the face of the waters in Genesis 1:2.5.God said, "Let there be light," and there was light in Genesis 1:3.6.God divided the light from the darkness in Genesis 1:4.7.', 'God called the light "Day" and the darkness "Night" in Genesis 1:5.8.One day consisted of an evening and a morning in Genesis 1:5.9.God said, "Let there be a firmament in the midst of the waters," in Genesis 1:6.10.God made the firmament and divided the waters in Genesis 1:7.11.God called the firmament "Heaven" in Genesis 1:8.12.A second day consisted of an evening and a morning in Genesis 1:8.13.God said, "Let the waters under the heaven be gathered together," in Genesis 1:9.14.', 'God created dry land and called it "Earth" in Genesis 1:10.15.God called the gathering of the waters "Seas" in Genesis 1:10.16.God saw that the creation was good in Genesis 1:10.17.God said, "Let the earth put forth grass, herb, and fruit tree," in Genesis 1:11.18.The earth brought forth grass, herb, and fruit tree in Genesis 1:12.19.God saw that the creation was good in Genesis 1:12.20.A third day consisted of an evening and a morning in Genesis 1:13.21.', 'God said, "Let there be lights in the firmament of the heaven," in Genesis 1:14.22.God created lights to divide the day from the night in Genesis 1:14.23.The lights were for signs, seasons, days, and years in Genesis 1:14.24.God made the two great lights, the greater light and the lesser light, in Genesis 1:16.25.The greater light ruled the day, and the lesser light ruled the night in Genesis 1:16.26.God set the lights in the firmament of the heaven in Genesis 1:17.27.', 'A fourth day consisted of an evening and a morning in Genesis 1:19.28.God said, "Let the waters bring forth the moving creature," in Genesis 1:20.29.God created great sea-monsters and living creatures in Genesis 1:21.30.God created winged fowl after their kinds in Genesis 1:21.31.God saw that the creation was good in Genesis 1:21.32.God blessed the living creatures in Genesis 1:22.33.God said, "Be fruitful, and multiply, and fill the waters," in Genesis 1:22.34.', 'A fifth day consisted of an evening and a morning in Genesis 1:23.35.God said, "Let the earth bring forth the living creature," in Genesis 1:24.36.God created cattle, creeping things, and beasts of the earth in Genesis 1:25.37.God saw that the creation was good in Genesis 1:25.38.God said, "Let us make man in our image," in Genesis 1:26.39.God created man in his own image in Genesis 1:27.40.God created man and woman in Genesis 1:27.41.God blessed man and woman in Genesis 1:28.42.', 'God said, "Be fruitful, and multiply, and replenish the earth," in Genesis 1:28.43.God gave man dominion over the earth in Genesis 1:28.44.God said, "Behold, I have given you every herb yielding seed," in Genesis 1:29.45.God gave man every green herb for meat in Genesis 1:30.46.God gave every beast of the earth, every fowl of the air, and every living thing green herbs for meat in Genesis 1:30.47.God saw that everything he had made was very good in Genesis 1:31.48.', 'A sixth day consisted of an evening and a morning in Genesis 1:31.']
# 8
# <style_analysis>**Analysis:**
#
# **Format and Genre:** The text is a biblical passage, specifically the opening chapter of the book of Genesis in the King James Version (KJV) of the Bible. It belongs to the genre of sacred scripture, specifically a creation narrative.
#
# **Writing Style:** The writing style is formal, ornate, and lyrical, with a focus on poetic and repetitive language. The use of parallel structures, metaphors, and personification creates a rich and evocative tone. The</style_analysis>
# Constructed KG:
# <segment 1>
#
#               'English Revised Version (ERV) of the Bible': {
#                   'relations': {
#                       'contains': 'Book of Genesis',
#                       'published_in': '19th century'
#                   },
#                   'attributes': {
#                       'genre': 'Sacred scripture',
#                       'language': 'English'
#                   }
#               },
#               'Book of Genesis': {
#                   'relations': {
#                       'contained_in': 'English Revised Version (ERV) of the Bible',
#                       'creation_narrative': true
#                   },
#                   'attributes': {
#                       'chapter': '1',
#                       'verse': '1',
#                       'content': 'God created the heaven and the earth'
#                   }
#               },
#               'Genesis 1:1': {
#                   'relations': {
#                       'states': 'God created the heaven and the earth',
#                       'located_in': 'Book of Genesis'
#                   },
#                   'attributes': {
#                       'content': 'In the beginning, God created the heaven and the earth'
#                   }
#               },
#               'God': {
#                   'relations': {
#                       'created': 'Heaven and earth',
#                       'spoke': 'Let there be light'
#                   },
#                   'attributes': {
#                       'nature': 'Supernatural',
#                       'role': 'Creator'
#                   }
#               },
#               'Heaven and earth': {
#                   'relations': {
#                       'created_by': 'God'
#                   },
#                   'attributes': {
#                       'state': 'Initially waste and void'
#                   }
#               },
#               'Genesis 1:2': {
#                   'relations': {
#                       'states': 'The earth was waste and void, with darkness on its face'
#                   },
#                   'attributes': {
#                       'content': 'The earth was waste and void, and darkness was on the face of the deep'
#                   }
#               },
#               'Genesis 1:3': {
#                   'relations': {
#                       'states': 'God said, "Let there be light," and there was light'
#                   },
#                   'attributes': {
#                       'content': 'And God said, "Let there be light," and there was light'
#                   }
#               },
#               'Genesis 1:4': {
#                   'relations': {
#                       'states': 'God divided the light from the darkness'
#                   },
#                   'attributes': {
#                       'content': 'And God divided the light from the darkness'
#                   }
#               }
# <source_sentence_min_hash: [ 78763342  20363676  44306063  80487212  53456555 148603317  23728036
#  136421442  47429823 224390667  52562077  52778338  15970207  33369381
#   54450694  14497997] >
# </segment 1>
#
# Recontructed Segment:
#
# In the English Revised Version (ERV) of the Bible, the Book of Genesis is a foundational text that contains the creation narrative. The ERV was published in the 19th century and is a sacred scripture written in the English language. Specifically, the Book of Genesis is a crucial part of this text, starting with Chapter 1, Verse 1, which states, "In the beginning, God created the heaven and the earth" (Genesis 1:1).
#
# According to the knowledge graph, God is the creator of the heaven and the earth, and He is described as a supernatural being with a role as the Creator. The heaven and earth, which were created by God, were initially waste and void, with darkness on their face (Genesis 1:2). However, God spoke and said, "Let there be light," and there was light (Genesis 1:3). This marked a significant event in the creation narrative, as God divided the light from the darkness (Genesis 1:4).
#
# These early verses of the Book of Genesis provide a foundational account of the creation of the world and the role of God as the Creator. The ERV's translation of these verses offers a clear and concise understanding of the biblical narrative, which has been a cornerstone of Christian theology for centuries.
#
#
# Constructed KG:
# <segment 2>
#
#               'Genesis 1:5': {
#                   'relations': {
#                       'states': 'God called the light "Day" and the darkness "Night"'
#                   },
#                   'attributes': {
#                       'content': 'God called the light "Day" and the darkness "Night"'
#                   }
#               },
#               'Genesis 1:8': {
#                   'relations': {
#                       'states': 'One day consisted of an evening and a morning'
#                   },
#                   'attributes': {
#                       'content': 'One day consisted of an evening and a morning'
#                   }
#               },
#               'Genesis 1:6': {
#                   'relations': {
#                       'states': 'God said, "Let there be a firmament in the midst of the waters"'
#                   },
#                   'attributes': {
#                       'content': 'God said, "Let there be a firmament in the midst of the waters"'
#                   }
#               },
#               'Genesis 1:7': {
#                   'relations': {
#                       'states': 'God made the firmament and divided the waters'
#                   },
#                   'attributes': {
#                       'content': 'God made the firmament and divided the waters'
#                   }
#               },
#               'Genesis 1:8': {
#                   'relations': {
#                       'states': 'God called the firmament "Heaven"'
#                   },
#                   'attributes': {
#                       'content': 'God called the firmament "Heaven"'
#                   }
#               },
#               'Genesis 1:9': {
#                   'relations': {
#                       'states': 'One second day consisted of an evening and a morning'
#                   },
#                   'attributes': {
#                       'content': 'One second day consisted of an evening and a morning'
#                   }
#               },
#               'Genesis 1:9': {
#                   'relations': {
#                       'states': 'God said, "Let the waters under the heaven be gathered together"'
#                   },
#                   'attributes': {
#                       'content': 'God said, "Let the waters under the heaven be gathered together"'
#                   }
#               }
# <source_sentence_min_hash: [151437886  59783394  75883492 453472904  29001415 148603317 122589839
#  252994202 153079691 141861952  98286111  74243328 187731381  35256622
#  401740157  14497997] >
# </segment 2>
#
# Recontructed Segment:
#
# Continuing from the previous account of creation, we find that God's creative work continues with the establishment of the firmament. According to Genesis 1:6, God says, "Let there be a firmament in the midst of the waters," which marks a significant event in shaping the world as we know it. This firmament would later be called "Heaven" (Genesis 1:8).
#
# As the narrative unfolds, we learn that God made the firmament and divided the waters (Genesis 1:7). This division is crucial, as it sets the stage for the separation of the waters above from the waters below. The firmament, now referred to as "Heaven," serves as a boundary between these two realms.
#
# On the second day, God's creative work continued with the gathering of the waters under the heaven (Genesis 1:9). This process involved the collection of the waters, which would eventually form the oceans and seas we see today. The day consisted of an evening and a morning, just like the previous day (Genesis 1:8 and 1:9).
#
# As the creation narrative progresses, we see God's meticulous attention to detail and His desire to create a world that is both beautiful and functional. The establishment of the firmament and the division of the waters are key elements in this process, setting the stage for the next phase of creation.
#
#
# Constructed KG:
# Constructed KG:
# <segment 3>
#
#               'Genesis 1:10': {
#                   'relations': {
#                       'states': 'God created dry land and called it "Earth"'
#                   },
#                   'attributes': {
#                       'content': 'And God said, "Let the waters under the heaven be gathered together unto one place, and let the dry land appear: and it was so."'
#                   }
#               },
#               'Genesis 1:11': {
#                   'relations': {
#                       'states': 'God said, "Let the earth put forth grass, herb, and fruit tree"'
#                   },
#                   'attributes': {
#                       'content': 'And God said, "Let the earth bring forth grass, the herb yielding seed, and the fruit tree yielding fruit after his kind, whose seed is in itself, upon the earth: and it was so."'
#                   }
#               },
#               'Genesis 1:12': {
#                   'relations': {
#                       'states': 'The earth brought forth grass, herb, and fruit tree'
#                   },
#                   'attributes': {
#                       'content': 'And the earth brought forth grass, and herb yielding seed after his kind, and the tree yielding fruit, whose seed was in itself. And God saw that it was good.'
#                   }
#               },
#               'Genesis 1:13': {
#                   'relations': {
#                       'states': 'A third day consisted of an evening and a morning'
#                   },
#                   'attributes': {
#                       'content': 'And the evening and the morning were the third day.'
#                   }
#               },
#               'Earth': {
#                   'relations': {
#                       'created_by': 'God',
#                       'called_by': 'God'
#                   },
#                   'attributes': {
#                       'description': 'Dry land'
#                   }
#               },
#               'Seas': {
#                   'relations': {
#                       'created_by': 'God',
#                       'called_by': 'God'
#                   },
#                   'attributes': {
#                       'description': 'Gathering of the waters'
#                   }
#               },
#               'God': {
#                   'relations': {
#                       'created': 'Dry land and Seas',
#                       'called': 'Earth and Seas'
#                   },
#                   'attributes': {
#                       'nature': 'Supernatural',
#                       'role': 'Creator'
#                   }
#               }
# <source_sentence_min_hash: [129763488  97085922  58499433 205665664   4164469  28097237  42853146
#  114660954  37381873  25782497  14003320  74243328       370 304926114
#  109254202 104031572] >
# </segment 3>
#
# Recontructed Segment:
#
# As we continue from the previous account of creation, we see that God's creative work continues with the establishment of the earth and the seas. According to Genesis 1:10, God created dry land and called it "Earth." This marks a significant event in the creation narrative, as the earth is now a tangible and habitable place.
#
# The process of creating the earth is described in Genesis 1:10, where God says, "Let the waters under the heaven be gathered together unto one place, and let the dry land appear: and it was so." This command from God resulted in the gathering of the waters, which would eventually form the oceans and seas we see today.
#
# On the third day, God's creative work continued with the production of vegetation. According to Genesis 1:11, God said, "Let the earth bring forth grass, the herb yielding seed, and the fruit tree yielding fruit after his kind, whose seed is in itself, upon the earth: and it was so." This command from God resulted in the earth bringing forth grass, herb, and fruit trees, which were designed to reproduce after their own kind.
#
# As we observe the creation narrative, we see that God's attention to detail is evident in the creation of the earth and its inhabitants. The earth was designed to be a beautiful and functional place, with vegetation that would provide sustenance for the creatures that would eventually inhabit it.
#
# The third day consisted of an evening and a morning, just like the previous days (Genesis 1:13). This marks a significant event in the creation narrative, as it sets the stage for the next phase of creation.
#
# The earth, which was created by God, is described as dry land (Genesis 1:10). This is in contrast to the seas, which were also created by God and are described as the gathering of the waters (Genesis 1:10).
#
# God, who is described as a supernatural being with a role as the Creator, is credited with creating the earth and the seas. He is also credited with calling the earth "Earth" and the seas "Seas" (Genesis 1:10).
#
# In summary, the third day of creation saw the establishment of the earth and the seas, as well as the production of vegetation. The earth was designed to be a beautiful and functional place, with vegetation that would provide sustenance for the creatures that would eventually inhabit it.
#
#
# Constructed KG:
# <segment 4>
#
#               'Genesis 1:14': {
#                   'relations': {
#                       'states': 'God said, "Let there be lights in the firmament of the heaven"'
#                   },
#                   'attributes': {
#                       'content': 'God said, "Let there be lights in the firmament of the heaven"'
#                   }
#               },
#               'Genesis 1:22': {
#                   'relations': {
#                       'states': 'God said, "Let there be lights in the firmament of the heaven,"'
#                   },
#                   'attributes': {
#                       'content': 'God said, "Let there be lights in the firmament of the heaven,"'
#                   }
#               },
#               'Genesis 1:14.23': {
#                   'relations': {
#                       'states': 'God created lights to divide the day from the night'
#                   },
#                   'attributes': {
#                       'content': 'God created lights to divide the day from the night'
#                   }
#               },
#               'Genesis 1:14.24': {
#                   'relations': {
#                       'states': 'The lights were for signs, seasons, days, and years'
#                   },
#                   'attributes': {
#                       'content': 'The lights were for signs, seasons, days, and years'
#                   }
#               },
#               'Genesis 1:16': {
#                   'relations': {
#                       'states': 'God made the two great lights, the greater light and the lesser light'
#                   },
#                   'attributes': {
#                       'content': 'God made the two great lights, the greater light and the lesser light'
#                   }
#               },
#               'Genesis 1:16.25': {
#                   'relations': {
#                       'states': 'God made the two great lights, the greater light and the lesser light'
#                   },
#                   'attributes': {
#                       'content': 'God made the two great lights, the greater light and the lesser light'
#                   }
#               },
#               'Genesis 1:16.26': {
#                   'relations': {
#                       'states': 'The greater light ruled the day, and the lesser light ruled the night'
#                   },
#                   'attributes': {
#                       'content': 'The greater light ruled the day, and the lesser light ruled the night'
#                   }
#               },
#               'Genesis 1:17': {
#                   'relations': {
#                       'states': 'God set the lights in the firmament of the heaven'
#                   },
#                   'attributes': {
#                       'content': 'God set the lights in the firmament of the heaven'
#                   }
#               },
#               'Genesis 1:27': {
#                   'relations': {
#                       'states': 'God set the lights in the firmament of the heaven'
#                   },
#                   'attributes': {
#                       'content': 'God set the lights in the firmament of the heaven'
#                   }
#               },
#               'Lights': {
#                   'relations': {
#                       'created_by': 'God',
#                       'divide': 'Day and night'
#                   },
#                   'attributes': {
#                       'description': 'For signs, seasons, days, and years'
#                   }
#               },
#               'Firmament of the heaven': {
#                   'relations': {
#                       'contains': 'Lights',
#                       'set_by': 'God'
#                   },
#                   'attributes': {
#                       'description': 'The expanse of the sky'
#                   }
#               },
#               'God': {
#                   'relations': {
#                       'created': 'Lights',
#                       'set': 'Lights in the firmament of the heaven'
#                   },
#                   'attributes': {
#                       'nature': 'Supernatural',
#                       'role': 'Creator'
#                   }
#               }
# <source_sentence_min_hash: [ 84401073  97085922  58499433 252271711  29001415  49989629 224035898
#  238582152  11338106 141861952  98286111  74243328   4691642  66752168
#  232893574 397363835] >
# </segment 4>
#
# Recontructed Segment:
#
# As we continue from the previous account of creation, we see that God's creative work continues with the establishment of the celestial bodies. According to Genesis 1:14, God said, "Let there be lights in the firmament of the heaven." This marked a significant event in the creation narrative, as it introduced the concept of light and darkness.
#
# The lights, which were created by God, were designed to divide the day from the night (Genesis 1:14.23). This was a crucial aspect of the creation narrative, as it established the cycle of day and night that would govern the earth's rhythms. The lights were also intended to serve as signs, seasons, days, and years (Genesis 1:14.24).
#
# God made the two great lights, the greater light and the lesser light, to rule over the day and night, respectively (Genesis 1:16.25-26). The greater light, which is often interpreted as the sun, ruled the day, while the lesser light, which is often interpreted as the moon, ruled the night (Genesis 1:16.26). God set the lights in the firmament of the heaven, creating a beautiful and functional celestial display (Genesis 1:17, 1:27).
#
# The firmament of the heaven, which was created by God, contains the lights and serves as a boundary between the waters above and the waters below (Genesis 1:17). The firmament is described as the expanse of the sky, and it plays a crucial role in the creation narrative as a separator of the celestial and terrestrial realms.
#
# In summary, the fourth day of creation saw the establishment of the celestial bodies, including the lights that divide the day from the night and serve as signs, seasons, days, and years. The lights, which were created by God, were designed to rule over the day and night, and the firmament of the heaven was set as a boundary between the waters above and the waters below.
#
#
# Constructed KG:
# <segment 5>
#
#               'Genesis 1:19.28': {
#                   'relations': {
#                       'states': 'A fourth day consisted of an evening and a morning'
#                   },
#                   'attributes': {
#                       'content': 'And God said, "Let the waters bring forth the moving creature," and it was so.'
#                   }
#               },
#               'Genesis 1:20.29': {
#                   'relations': {
#                       'states': 'God said, "Let the waters bring forth the moving creature,"'
#                   },
#                   'attributes': {
#                       'content': 'God said, "Let the waters bring forth the moving creature," and it was so.'
#                   }
#               },
#               'Genesis 1:21.30': {
#                   'relations': {
#                       'states': 'God created great sea-monsters and living creatures'
#                   },
#                   'attributes': {
#                       'content': 'And God created great beasts of the sea and every living creature that moveth, which the waters brought forth abundantly, after their kind, and every winged fowl after his kind: and God saw that it was good.'
#                   }
#               },
#               'Genesis 1:21.31': {
#                   'relations': {
#                       'states': 'God created winged fowl after their kinds'
#                   },
#                   'attributes': {
#                       'content': 'And God created great beasts of the sea and every living creature that moveth, which the waters brought forth abundantly, after their kind, and every winged fowl after his kind: and God saw that it was good.'
#                   }
#               },
#               'Genesis 1:21.32': {
#                   'relations': {
#                       'states': 'God saw that the creation was good'
#                   },
#                   'attributes': {
#                       'content': 'And God saw that it was good.'
#                   }
#               },
#               'Genesis 1:22.33': {
#                   'relations': {
#                       'states': 'God blessed the living creatures'
#                   },
#                   'attributes': {
#                       'content': 'And God blessed them, saying, Be fruitful, and multiply, and fill the waters in the seas, and let fowl multiply in the earth.'
#                   }
#               },
#               'Genesis 1:22.34': {
#                   'relations': {
#                       'states': 'God said, "Be fruitful, and multiply, and fill the waters,"'
#                   },
#                   'attributes': {
#                       'content': 'And God blessed them, saying, Be fruitful, and multiply, and fill the waters in the seas, and let fowl multiply in the earth.'
#                   }
#               },
#               'God': {
#                   'relations': {
#                       'created': 'Great sea-monsters and living creatures',
#                       'created': 'Winged fowl after their kinds',
#                       'saw': 'That the creation was good',
#                       'blessed': 'Living creatures'
#                   },
#                   'attributes': {
#                       'nature': 'Supernatural',
#                       'role': 'Creator'
#                   }
#               },
#               'Great sea-monsters': {
#                   'relations': {
#                       'created_by': 'God'
#                   },
#                   'attributes': {
#                       'description': 'Creatures of the sea'
#                   }
#               },
#               'Living creatures': {
#                   'relations': {
#                       'created_by': 'God',
#                       'blessed_by': 'God'
#                   },
#                   'attributes': {
#                       'description': 'Creatures of the sea and air'
#                   }
#               },
#               'Winged fowl': {
#                   'relations': {
#                       'created_by': 'God'
#                   },
#                   'attributes': {
#                       'description': 'Birds'
#                   }
#               },
#               'Creation': {
#                   'relations': {
#                       'created_by': 'God'
#                   },
#                   'attributes': {
#                       'description': 'The universe and all living things'
#                   }
#               }
# <source_sentence_min_hash: [ 84401073  97085922  20675186   3295546  14019373  36415073 182108133
#  132971143  70491035 236986188  22907577   6322459 187731381  19170202
#  105881313 179688178] >
# </segment 5>
#
# Recontructed Segment:
#
# As we continue from the previous account of creation, we see that God's creative work continues with the establishment of the celestial bodies. On the fourth day, God said, "Let the waters bring forth the moving creature," and it was so (Genesis 1:19-28). This marked a significant event in the creation narrative, as it introduced the concept of living creatures that inhabit the waters.
#
# According to the knowledge graph, God created great sea-monsters and living creatures, which were designed to reproduce after their own kind (Genesis 1:21-30). These creatures were abundant in the waters, and God saw that they were good (Genesis 1:21-32). Additionally, God created winged fowl after their kinds, which were also designed to reproduce after their own kind (Genesis 1:21-31).
#
# As the creation narrative unfolds, we see that God blessed the living creatures, saying, "Be fruitful, and multiply, and fill the waters in the seas, and let fowl multiply in the earth" (Genesis 1:22-33). This blessing was a significant event in the creation narrative, as it marked the beginning of the reproductive cycle of the creatures.
#
# The knowledge graph also reveals that God is the creator of the great sea-monsters, living creatures, and winged fowl (Genesis 1:21-30). These creatures were designed to inhabit the waters and the earth, and they were created by God as part of His overall plan for creation.
#
# In summary, the fourth day of creation saw the establishment of the celestial bodies, including the living creatures that inhabit the waters. God created great sea-monsters and living creatures, which were designed to reproduce after their own kind. He also created winged fowl after their kinds, and blessed the living creatures, saying, "Be fruitful, and multiply, and fill the waters in the seas, and let fowl multiply in the earth."
#
# The creation narrative continues to unfold, revealing God's meticulous attention to detail and His desire to create a world that is both beautiful and functional. The establishment of the celestial bodies and the living creatures marks a significant event in the creation narrative, as it sets the stage for the next phase of creation.
#
# As we continue to explore the creation narrative, we see that God's creative work continues with the establishment of the land and the creatures that inhabit it. On the fifth day, God said, "Let the waters bring forth the moving creature," and it was so (Genesis 1:20-29). This marked a significant event in the creation narrative, as it introduced the concept of living creatures that inhabit the land.
#
# According to the knowledge graph, God created great beasts of the sea and every living creature that moveth, which the waters brought forth abundantly, after their kind (Genesis 1:21-30). These creatures were designed to inhabit the land and the waters, and they were created by God as part of His overall plan for creation.
#
# The knowledge graph also reveals that God saw that the creation was good (Genesis 1:21-32). This marked a significant event in the creation narrative, as it revealed God's pleasure and satisfaction with the creation.
#
# In summary, the fifth day of creation saw the establishment of the land and the creatures that inhabit it. God created great beasts of the sea and every living creature that moveth, which the waters brought forth abundantly, after their kind. He also saw that the creation was good, revealing His pleasure and satisfaction with the creation.
#
# The creation narrative continues to unfold, revealing God's meticulous attention to detail and His desire to create a world that is both beautiful and functional. The establishment of the land and the creatures marks a significant event in the creation narrative, as it sets the stage for the next phase of creation.
#
#
# Constructed KG:
# <segment 6>
#
#               'Genesis 1:23.35': {
#                   'relations': {
#                       'states': 'A fifth day consisted of an evening and a morning'
#                   },
#                   'attributes': {
#                       'content': 'And the evening and the morning were the fifth day.'
#                   }
#               },
#               'Genesis 1:24.36': {
#                   'relations': {
#                       'states': 'God said, "Let the earth bring forth the living creature,"'
#                   },
#                   'attributes': {
#                       'content': 'God said, "Let the earth bring forth the living creature,"'
#                   }
#               },
#               'Genesis 1:25.37': {
#                   'relations': {
#                       'states': 'God created cattle, creeping things, and beasts of the earth'
#                   },
#                   'attributes': {
#                       'content': 'And God made the beast of the earth after his kind, and cattle after their kind, and every thing that creepeth upon the earth after his kind: and God saw that it was good.'
#                   }
#               },
#               'Genesis 1:25.38': {
#                   'relations': {
#                       'states': 'God saw that the creation was good'
#                   },
#                   'attributes': {
#                       'content': 'And God saw that it was good.'
#                   }
#               },
#               'Genesis 1:26.39': {
#                   'relations': {
#                       'states': 'God said, "Let us make man in our image,"'
#                   },
#                   'attributes': {
#                       'content': 'God said, "Let us make man in our image, after our likeness: and let them have dominion over the fish of the sea, and over the fowl of the air, and over the cattle, and over all the earth, and over every creeping thing that creepeth upon the earth."'
#                   }
#               },
#               'Genesis 1:27.40': {
#                   'relations': {
#                       'states': 'God created man in his own image'
#                   },
#                   'attributes': {
#                       'content': 'So God created man in his own image, in the image of God created he him; male and female created he them.'
#                   }
#               },
#               'Genesis 1:27.41': {
#                   'relations': {
#                       'states': 'God created man and woman'
#                   },
#                   'attributes': {
#                       'content': 'So God created man in his own image, in the image of God created he him; male and female created he them.'
#                   }
#               },
#               'Genesis 1:28.42': {
#                   'relations': {
#                       'states': 'God blessed man and woman'
#                   },
#                   'attributes': {
#                       'content': 'And God blessed them, and God said unto them, Be fruitful, and multiply, and replenish the earth, and subdue it: and have dominion over the fish of the sea, and over the fowl of the air, and over every living thing that moveth upon the earth.'
#                   }
#               },
#               'God': {
#                   'relations': {
#                       'said': 'Let the earth bring forth the living creature',
#                       'created': 'Cattle, creeping things, and beasts of the earth',
#                       'saw': 'That the creation was good',
#                       'said': 'Let us make man in our image',
#                       'created': 'Man in his own image',
#                       'created': 'Man and woman',
#                       'blessed': 'Man and woman'
#                   },
#                   'attributes': {
#                       'nature': 'Supernatural',
#                       'role': 'Creator'
#                   }
#               },
#               'Man and woman': {
#                   'relations': {
#                       'created_by': 'God'
#                   },
#                   'attributes': {
#                       'description': 'First humans'
#                   }
#               },
#               'Creation': {
#                   'relations': {
#                       'created_by': 'God'
#                   },
#                   'attributes': {
#                       'description': 'The universe and all living things'
#                   }
#               },
#               'Day': {
#                   'relations': {
#                       'consisted_of': 'Evening and morning'
#                   },
#                   'attributes': {
#                       'number': 'Fifth'
#                   }
#               },
#               'Earth': {
#                   'relations': {
#                       'brought_forth': 'Living creature'
#                   },
#                   'attributes': {
#                       'description': 'Planet where humans live'
#                   }
#               },
#               'Living creature': {
#                   'relations': {
#                       'brought_forth_by': 'Earth'
#                   },
#                   'attributes': {
#                       'description': 'Animals and humans'
#                   }
#               }
# <source_sentence_min_hash: [297616339  97085922  58499433  50682523  14019373  53865188  65341913
#  132971143  80612661 236986188  98286111  35725425  33479172 269371254
#  360091704 331264442] >
# </segment 6>
#
# Recontructed Segment:
#
# As we continue from the previous account of creation, we see that God's creative work continues with the establishment of the land and the creatures that inhabit it. On the fifth day, God said, "Let the earth bring forth the living creature," and it was so (Genesis 1:24). This marked a significant event in the creation narrative, as it introduced the concept of living creatures that inhabit the land.
#
# According to the knowledge graph, God created cattle, creeping things, and beasts of the earth, which were designed to inhabit the land and the waters (Genesis 1:25). These creatures were abundant in the earth, and God saw that they were good (Genesis 1:25). This marked a significant event in the creation narrative, as it revealed God's pleasure and satisfaction with the creation.
#
# On the fifth day, God also said, "Let us make man in our image," and it was so (Genesis 1:26). This marked a significant event in the creation narrative, as it introduced the concept of humanity. God created man in His own image, in the image of God created He him; male and female created He them (Genesis 1:27). This was a crucial aspect of the creation narrative, as it established the relationship between God and humanity.
#
# God blessed man and woman, saying, "Be fruitful, and multiply, and replenish the earth, and subdue it: and have dominion over the fish of the sea, and over the fowl of the air, and over every living thing that moveth upon the earth" (Genesis 1:28). This blessing was a significant event in the creation narrative, as it marked the beginning of humanity's role in the creation.
#
# In summary, the fifth day of creation saw the establishment of the land and the creatures that inhabit it, including humanity. God created cattle, creeping things, and beasts of the earth, and saw that they were good. He also created man and woman in His own image, and blessed them to have dominion over the earth.
#
# The creation narrative continues to unfold, revealing God's meticulous attention to detail and His desire to create a world that is both beautiful and functional. The establishment of the land and the creatures, including humanity, marks a significant event in the creation narrative, as it sets the stage for the next phase of creation.
#
#
# Constructed KG:
# <segment 7>
#
#               'Genesis 1:28': {
#                   'relations': {
#                       'states': 'God said, "Be fruitful, and multiply, and replenish the earth,"'
#                   },
#                   'attributes': {
#                       'content': 'God said, "Be fruitful, and multiply, and replenish the earth,"'
#                   }
#               },
#               'Genesis 1:28': {
#                   'relations': {
#                       'states': 'God gave man dominion over the earth'
#                   },
#                   'attributes': {
#                       'content': 'God gave man dominion over the earth'
#                   }
#               },
#               'Genesis 1:29': {
#                   'relations': {
#                       'states': 'God said, "Behold, I have given you every herb yielding seed,"'
#                   },
#                   'attributes': {
#                       'content': 'God said, "Behold, I have given you every herb yielding seed,"'
#                   }
#               },
#               'Genesis 1:29': {
#                   'relations': {
#                       'states': 'God gave man every green herb for meat'
#                   },
#                   'attributes': {
#                       'content': 'God gave man every green herb for meat'
#                   }
#               },
#               'Genesis 1:30': {
#                   'relations': {
#                       'states': 'God gave every beast of the earth, every fowl of the air, and every living thing green herbs for meat'
#                   },
#                   'attributes': {
#                       'content': 'God gave every beast of the earth, every fowl of the air, and every living thing green herbs for meat'
#                   }
#               },
#               'Genesis 1:31': {
#                   'relations': {
#                       'states': 'God saw that everything he had made was very good'
#                   },
#                   'attributes': {
#                       'content': 'God saw that everything he had made was very good'
#                   }
#               },
#               'God': {
#                   'relations': {
#                       'said': 'Be fruitful, and multiply, and replenish the earth',
#                       'gave': 'Man dominion over the earth',
#                       'said': 'Behold, I have given you every herb yielding seed',
#                       'gave': 'Man every green herb for meat',
#                       'gave': 'Every beast of the earth, every fowl of the air, and every living thing green herbs for meat',
#                       'saw': 'That everything he had made was very good'
#                   },
#                   'attributes': {
#                       'nature': 'Supernatural',
#                       'role': 'Creator'
#                   }
#               },
#               'Man': {
#                   'relations': {
#                       'given': 'Dominion over the earth',
#                       'given': 'Every green herb for meat'
#                   },
#                   'attributes': {
#                       'description': 'First humans'
#                   }
#               },
#               'Earth': {
#                   'relations': {
#                       'given': 'Dominion by man'
#                   },
#                   'attributes': {
#                       'description': 'Planet where humans live'
#                   }
#               },
#               'Herb': {
#                   'relations': {
#                       'given': 'For meat by God'
#                   },
#                   'attributes': {
#                       'description': 'Plant yielding seed'
#                   }
#               },
#               'Beast': {
#                   'relations': {
#                       'given': 'Green herbs for meat by God'
#                   },
#                   'attributes': {
#                       'description': 'Animals of the earth'
#                   }
#               },
#               'Fowl': {
#                   'relations': {
#                       'given': 'Green herbs for meat by God'
#                   },
#                   'attributes': {
#                       'description': 'Birds of the air'
#                   }
#               },
#               'Living thing': {
#                   'relations': {
#                       'given': 'Green herbs for meat by God'
#                   },
#                   'attributes': {
#                       'description': 'All living creatures'
#                   }
#               },
#               'Creation': {
#                   'relations': {
#                       'seen': 'By God as very good'
#                   },
#                   'attributes': {
#                       'description': 'The universe and all living things'
#                   }
#               }
# <source_sentence_min_hash: [   102083  97085922  54054364 211214607  78218248   4416429  22835310
#  136421442 104241235 231507963 144317413  11777478 228521625   4002973
#   14137359  32762412] >
# </segment 7>
#
# Recontructed Segment:
#
# As we continue from the previous account of creation, we see that God's creative work continues with the establishment of humanity. According to Genesis 1:26, God said, "Let us make man in our image," and it was so. This marked a significant event in the creation narrative, as it introduced the concept of humanity.
#
# God created man in His own image, in the image of God created He him; male and female created He them (Genesis 1:27). This was a crucial aspect of the creation narrative, as it established the relationship between God and humanity.
#
# God blessed man and woman, saying, "Be fruitful, and multiply, and replenish the earth, and subdue it: and have dominion over the fish of the sea, and over the fowl of the air, and over every living thing that moveth upon the earth" (Genesis 1:28). This blessing was a significant event in the creation narrative, as it marked the beginning of humanity's role in the creation.
#
# As part of this blessing, God gave man dominion over the earth (Genesis 1:28). This means that humanity was entrusted with the responsibility of caring for and managing the earth and its resources. Additionally, God gave man every green herb for meat (Genesis 1:29), providing humanity with a source of sustenance.
#
# Furthermore, God gave every beast of the earth, every fowl of the air, and every living thing green herbs for meat (Genesis 1:30). This indicates that God's creation was designed to be a harmonious and interconnected system, where all living things were able to coexist and thrive.
#
# Finally, God saw that everything he had made was very good (Genesis 1:31). This statement marks a significant moment in the creation narrative, as it highlights God's satisfaction and pleasure with the creation. It also serves as a testament to the beauty and wonder of God's creation.
#
# In summary, the sixth day of creation saw the establishment of humanity, with God creating man and woman in His own image. God blessed humanity, giving them dominion over the earth and providing them with a source of sustenance. Additionally, God saw that everything he had made was very good, highlighting the beauty and wonder of His creation.
#
# The creation narrative continues to unfold, revealing God's meticulous attention to detail and His desire to create a world that is both beautiful and functional. The establishment of humanity marks a significant event in the creation narrative, as it sets the stage for the next phase of creation.
#
#
# Constructed KG:
# <segment 8>
#
#               'Genesis 1:31': {
#                   'relations': {
#                       'consisted_of': 'Evening and morning'
#                   },
#                   'attributes': {
#                       'day_number': 'Sixth'
#                   }
#               },
#               'Genesis 1:31': {
#                   'relations': {
#                       'located_in': 'Book of Genesis'
#                   },
#                   'attributes': {
#                       'chapter': '1',
#                       'verse': '31'
#                   }
#               },
#               'Book of Genesis': {
#                   'relations': {
#                       'contains': 'Genesis 1:31'
#                   },
#                   'attributes': {
#                       'genre': 'Sacred scripture',
#                       'language': 'Hebrew'
#                   }
#               },
#               'Evening and morning': {
#                   'relations': {
#                       'consisted_of': 'Genesis 1:31'
#                   },
#                   'attributes': {
#                       'description': 'Period of time'
#                   }
#               }
# <source_sentence_min_hash: [ 297616339   97085922   91521943  257361572   14019373   89296115
#   192196507  158207789 1130178991  236986188   98286111   74243328
#   187731381  304926114  437098192  473762325] >
# </segment 8>
#
# Recontructed Segment:
#
# As we continue from the previous account of creation, we see that God's creative work is now complete. According to the knowledge graph, the sixth day of creation saw the establishment of humanity, with God creating man and woman in His own image (Genesis 1:26-27). This marked a significant event in the creation narrative, as it introduced� the concept of humanity and established the relationship between God and humanity.
#
# God blessed man and woman, saying, "Be fruitful, and multiply, and replenish the earth, and subdue it: and have dominion over the fish of the sea, and over the fowl of the air, and over every living thing that moveth upon the earth" (Genesis 1:28). This blessing was a significant event in the creation narrative, as it marked the beginning of humanity's role in the creation.
#
# As part of this blessing, God gave man dominion over the earth, entrusting humanity with the responsibility of caring for and managing the earth and its resources. Additionally, God gave man every green herb for meat, providing humanity with a source of sustenance (Genesis 1:29).
#
# Furthermore, God gave every beast of the earth, every fowl of the air, and every living thing green herbs for meat, indicating that God's creation was designed to be a harmonious and interconnected system, where all living things were able to coexist and thrive (Genesis 1:30).
#
# Finally, God saw that everything he had made was very good (Genesis 1:31). This statement marks a significant moment in the creation narrative,, as it highlights God's satisfaction and pleasure with the creation. It also marks the end of the creation story, as God's work is now complete.
#
# The knowledge graph reveals that Genesis 1:31 is a part of the Book of Genesis, a sacred scripture written in Hebrew (Book of Genesis). It is located in Chapter 1, Verse 31, and consists of the period of time known as "Evening and morning" (Genesis 1:31).
#
# In summary, the sixth day of creation saw the establishment of humanity, with God creating man and woman in His own image. God blessed humanity, giving them dominion over the earth and providing them with a source of sustenance. Additionally, God saw that everything he had made was very good, highlighting the beauty and wonder of His creation.
#
# The creation narrative comes to a close, revealing God's meticulous attention to detail and His desire to create a world that is both beautiful and functional. The establishment of humanity marks a significant event in the creation narrative, as it sets the stage for the next phase of creation.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 40
#      38     input_split_texts.append(input_string_list)
#      39     kg_for_input_split_texts.append(kg_results)
# ---> 40     KGs_so_far= "\n".join(kg_for_input_split_texts)
#      41     reconstruction_results_for_input_split_texts.append(reconstruction_results)
#      43 input_string_so_far_list.append(flatten_list_of_lists(input_split_texts))
#
# TypeError: sequence item 0: expected str instance, list found

# %%
df = pd.DataFrame({
    'Input_Texts': input_string_so_far_list,
    'Output_Graphs': all_kg_results,
    'Output_Reconstructions': all_reconstruction_results, })


print(df)

# print("500 word sample evalution:", "\n")
# base_cap_500, original_cap_500, knowledgegraph_cap_500, reconstruction_cap_500,QA_df = evaluate_peformance(df, 2,
#                                                                                                      "q_a_kg.parquet")

# print("No context correct answer percentage:", base_cap_500, "\n")
# print("Original context correct answer percentage:", original_cap_500, "\n")
# print("Knowledgegraph context correct answer percentage:", knowledgegraph_cap_500, "\n")
# print("Reconstruckted text context correct answer percentage:", reconstruction_cap_500, "\n")

# %%
df.to_csv("data/test.csv", encoding='utf-8', index=False)
#QA_df.to_csv("data/questions_answer_save_200.csv", encoding='utf-8', index=False)

# %%
# i = 0
# for input_text in concatenated_texts[2451:2500]:
#     print(i)
    
#     i = i+1
#     print(len(input_text))
    
#     #writing_style = get_style_genre(model_name, system_prompt, get_first_n_words(input_text, len(input_text))) #len(input_text) 1000
#     writing_style = get_style_genre(get_first_n_words(input_text, len(input_text)), model_name, system_prompt) #len(input_text) 1000
    
#     sentences = [input_text]
#     current_kg = []
#     current_kg.append("<style_analysis>" + writing_style + "</style_analysis>")
#     segment_nr = 1
#     reconstruction_so_far = ""
#     input_string_so_far = ""
#     for sentence in sentences:
#         input_string_so_far += sentence
#         if len(input_string_so_far) > stop_len:
#             break
#         current_kg_context = current_kg[-50:] if len(current_kg) > 50 else current_kg

#             # Concatenate the elements into a single string
#         current_kg_context = ' '.join(current_kg_context)

#         text = scripts.prompts.KG_format_example_prompt(current_kg_context, sentence)
        
        
#         try:
#             for i in range(2):
#                 knowledge_graph_segment = ask_LLM(model_name,
#                                                     "You are a very smart very intelligence assistant who is very helpful.",
#                                                     text, API_KEY, temperature=0.5, top_p=0.95, max_tokens=1000,
#                                                     frequency_penalty=1.1, presence_penalty=1.1)
#                 if not (extract_kg_content(knowledge_graph_segment) == None):
#                     break
#             try:
#                 current_kg.append("<segment " + str(segment_nr) + ">\n" + extract_kg_content(
#                         knowledge_graph_segment) + "<source_sentence_min_hash: " + str(
#                         create_minhash_vector(sentence)) + " >\n" + "</segment " + str(segment_nr) + ">\n")
#                 print("<segment " + str(segment_nr) + ">\n" + extract_kg_content(
#                         knowledge_graph_segment) + "<source_sentence_min_hash: " + str(
#                         create_minhash_vector(sentence)) + " >\n" + "</segment " + str(segment_nr) + ">\n")
#             except:
#                 current_kg.append(
#                         "<segment " + str(segment_nr) + ">\n" + knowledge_graph_segment + "<source_sentence_min_hash: " + str(
#                             create_minhash_vector(sentence)) + " >\n" + "</segment " + str(segment_nr) + ">\n")
#                 print("<segment " + str(segment_nr) + ">\n" + knowledge_graph_segment + "<source_sentence_min_hash: " + str(
#                         create_minhash_vector(sentence)) + " >\n" + "</segment " + str(segment_nr) + ">\n")

#             prompt = scripts.prompts.KG_reconstruction_prompt(reconstruction_so_far, current_kg)
#             for i in range(2):
#                 next_reconstruction = ask_LLM(model_name,
#                                                 "You are a very smart very intelligence assistant who is very helpful.",
#                                                 prompt, API_KEY, temperature=0.5, top_p=0.95, max_tokens=4000,
#                                                 frequency_penalty=1.1, presence_penalty=1.1)
#                 if not (extract_reconstruction_content(next_reconstruction) == None):
#                     break

#             reconstruction_so_far += extract_reconstruction_content(next_reconstruction)
#                 #print(reconstruction_so_far)

#             print(extract_reconstruction_content(next_reconstruction))
#             segment_nr += 1

#             #all_kg_results.append(current_kg)
#             #print("....................start....................................")
#             #print(current_kg.split("<source_sentence_min_hash:"))

#             #print("...............current kg........................")
#             #print(current_kg)

#             #kg_String = ''.join(current_kg)
        
#         except:
#             print("No Kg found")
            
#         try:
#             all_kg_results.append(current_kg)

#                 #print(".....................current kg end.........................")
#                 #all_reconstruction_results.append(reconstruction_so_far)
#                 #print(reconstruction_so_far.split("<source_sentence_min_hash:")[0])
#                 #reconstruction_String = ''.join(reconstruction_so_far)
#             all_reconstruction_results.append(reconstruction_so_far)
#                 #print("....................end....................................")

#             input_string_so_far_list.append(input_string_so_far)
        
#         except:
#             print("Pass because of no Kg found")

# %%
# i = 0

# for input_text in concatenated_texts[101:200]:
#     try:
#         print(i)

#         i = i+1
#         print(len(input_text))
#         writing_style = get_style_genre(get_first_n_words(input_text, len(input_text))) #len(input_text) 1000
#         sentences = [input_text]
#         current_kg = []
#         current_kg.append("<style_analysis>" + writing_style + "</style_analysis>")
#         segment_nr = 1
#         reconstruction_so_far = ""
#         input_string_so_far = ""
#         for sentence in sentences:
#             input_string_so_far += sentence
#             if len(input_string_so_far) > stop_len:
#                 break
#             current_kg_context = current_kg[-50:] if len(current_kg) > 50 else current_kg

#                 # Concatenate the elements into a single string
#             current_kg_context = ' '.join(current_kg_context)

#             text = scripts.prompts.KG_format_example_prompt(current_kg_context, sentence)

#             for i in range(2):
#                 knowledge_graph_segment = ask_LLM(model_name,
#                                                     "You are a very smart very intelligence assistant who is very helpful.",
#                                                     text, API_KEY, temperature=0.1, top_p=0.95, max_tokens=1000,
#                                                     frequency_penalty=1.1, presence_penalty=1.1)
#                 if not (extract_kg_content(knowledge_graph_segment) == None):
#                     break
#             try:
#                 current_kg.append("<segment " + str(segment_nr) + ">\n" + extract_kg_content(
#                         knowledge_graph_segment) + "<source_sentence_min_hash: " + str(
#                         create_minhash_vector(sentence)) + " >\n" + "</segment " + str(segment_nr) + ">\n")
#                 print("<segment " + str(segment_nr) + ">\n" + extract_kg_content(
#                         knowledge_graph_segment) + "<source_sentence_min_hash: " + str(
#                         create_minhash_vector(sentence)) + " >\n" + "</segment " + str(segment_nr) + ">\n")
#             except:
#                 current_kg.append(
#                         "<segment " + str(segment_nr) + ">\n" + knowledge_graph_segment + "<source_sentence_min_hash: " + str(
#                             create_minhash_vector(sentence)) + " >\n" + "</segment " + str(segment_nr) + ">\n")
#                 print("<segment " + str(segment_nr) + ">\n" + knowledge_graph_segment + "<source_sentence_min_hash: " + str(
#                         create_minhash_vector(sentence)) + " >\n" + "</segment " + str(segment_nr) + ">\n")

#             prompt = scripts.prompts.KG_reconstruction_prompt(reconstruction_so_far, current_kg)
#             for i in range(2):
#                 next_reconstruction = ask_LLM(model_name,
#                                                 "You are a very smart very intelligence assistant who is very helpful.",
#                                                 prompt, API_KEY, temperature=0.5, top_p=0.95, max_tokens=4000,
#                                                 frequency_penalty=1.1, presence_penalty=1.1)
#                 if not (extract_reconstruction_content(next_reconstruction) == None):
#                     break

#             reconstruction_so_far += extract_reconstruction_content(next_reconstruction)
#                 #print(reconstruction_so_far)

#             print(extract_reconstruction_content(next_reconstruction))
#             segment_nr += 1

#             #all_kg_results.append(current_kg)
#             #print("....................start....................................")
#             #print(current_kg.split("<source_sentence_min_hash:"))

#             #print("...............current kg........................")
#             #print(current_kg)

#             #kg_String = ''.join(current_kg)
#         all_kg_results.append(current_kg)

#             #print(".....................current kg end.........................")
#             #all_reconstruction_results.append(reconstruction_so_far)
#             #print(reconstruction_so_far.split("<source_sentence_min_hash:")[0])
#             #reconstruction_String = ''.join(reconstruction_so_far)
#         all_reconstruction_results.append(reconstruction_so_far)
#             #print("....................end....................................")

#         input_string_so_far_list.append(input_string_so_far)

#     except:
#         pass

# %%
# i = 0
# for input_text in concatenated_texts[0:1000]:
#     print(i)
    
#     i = i+1
#     print(len(input_text))
#     #print(input_text)
#     try:

#         writing_style = get_style_genre(get_first_n_words(input_text, len(input_text))) #len(input_text) 1000

#         # sentences= text_to_sentences(input_text)
#         # sentences =sentences_to_large_strings(sentences)
#         sentences = [input_text]
#         # print(sentences)
#         # continue
#         current_kg = []
#         current_kg.append("<style_analysis>" + writing_style + "</style_analysis>")
#         #print("<style_analysis>" + writing_style + "</style_analysis>")
#         segment_nr = 1
#         reconstruction_so_far = ""
#         input_string_so_far = ""
#         for sentence in sentences:
#             input_string_so_far += sentence
#             if len(input_string_so_far) > stop_len:
#                 break
#             #print("INPUT:", sentence)
#             # print("-----")
#             # '''
#             # prompt="""INPUT_TEXT:
#             # """+sentence+"""
#             # INSTRUCTION:
#             # Paraphrase the given input text so that every statement is rephrased into sentences that contain only three to ten words each.
#             #   Use a simple structure and make sure to retain all information, names, numbers, and dates from the original text, without losing
#             #     any information. The output text should consist exclusively of factual, neutrally phrased sentences that are three to ten words
#             #       long. All information must be preserved, but without any artistic nuances. Direct speech in the source text should not be
#             #         replicated as such, but it should be laid out in short sentences who said or did what in which order, ensuring a neutral,
#             #           information-rich text."""
    
#             # reply = ask_LLM ('NousResearch/Nous-Hermes-2-Mixtral-8x7B-DPO',
#             #   "You are a very smart very intelligence assistant who is very helpful.",
#             #     input_text , API_KEY ,temperature=0.5,top_p=0.95,max_tokens=1000, frequency_penalty=1.1,presence_penalty=1.1)
#             # '''

#             # Determine the slice of the last 50 elements (if the list has more than 50 elements)
#             current_kg_context = current_kg[-50:] if len(current_kg) > 50 else current_kg

#             # Concatenate the elements into a single string
#             current_kg_context = ' '.join(current_kg_context)

#             #print(".....................KG_format_example_prompt start.......................")
#             text = scripts.prompts.KG_format_example_prompt(current_kg_context, sentence)
#             #print(text)
#             #print(".....................KG_format_example_prompt end.......................")

#             for i in range(2):
#                 knowledge_graph_segment = ask_LLM(model_name,
#                                                 "You are a very smart very intelligence assistant who is very helpful.",
#                                                 text, API_KEY, temperature=0.1, top_p=0.95, max_tokens=1000,
#                                                 frequency_penalty=1.1, presence_penalty=1.1)
#                 if not (extract_kg_content(knowledge_graph_segment) == None):
#                     break
#             try:
#                 current_kg.append("<segment " + str(segment_nr) + ">\n" + extract_kg_content(
#                     knowledge_graph_segment) + "<source_sentence_min_hash: " + str(
#                     create_minhash_vector(sentence)) + " >\n" + "</segment " + str(segment_nr) + ">\n")
#                 print("<segment " + str(segment_nr) + ">\n" + extract_kg_content(
#                     knowledge_graph_segment) + "<source_sentence_min_hash: " + str(
#                     create_minhash_vector(sentence)) + " >\n" + "</segment " + str(segment_nr) + ">\n")
#             except:
#                 current_kg.append(
#                     "<segment " + str(segment_nr) + ">\n" + knowledge_graph_segment + "<source_sentence_min_hash: " + str(
#                         create_minhash_vector(sentence)) + " >\n" + "</segment " + str(segment_nr) + ">\n")
#                 print("<segment " + str(segment_nr) + ">\n" + knowledge_graph_segment + "<source_sentence_min_hash: " + str(
#                     create_minhash_vector(sentence)) + " >\n" + "</segment " + str(segment_nr) + ">\n")

#             prompt = scripts.prompts.KG_reconstruction_prompt(reconstruction_so_far, current_kg)
#             for i in range(2):
#                 next_reconstruction = ask_LLM(model_name,
#                                             "You are a very smart very intelligence assistant who is very helpful.",
#                                             prompt, API_KEY, temperature=0.5, top_p=0.95, max_tokens=4000,
#                                             frequency_penalty=1.1, presence_penalty=1.1)
#                 if not (extract_reconstruction_content(next_reconstruction) == None):
#                     break

#             reconstruction_so_far += extract_reconstruction_content(next_reconstruction)
#             #print(reconstruction_so_far)
            
#             print(extract_reconstruction_content(next_reconstruction))
#             segment_nr += 1
            
#         #all_kg_results.append(current_kg)
#         #print("....................start....................................")
#         #print(current_kg.split("<source_sentence_min_hash:"))
        
#         #print("...............current kg........................")
#         #print(current_kg)
        
#         #kg_String = ''.join(current_kg)
#         all_kg_results.append(current_kg)
        
#         #print(".....................current kg end.........................")
#         #all_reconstruction_results.append(reconstruction_so_far)
#         #print(reconstruction_so_far.split("<source_sentence_min_hash:")[0])
#         #reconstruction_String = ''.join(reconstruction_so_far)
#         all_reconstruction_results.append(reconstruction_so_far)
#         #print("....................end....................................")
        
#         input_string_so_far_list.append(input_string_so_far)
        
        
# #         print("\n")
# #         print("......all_kg_results............")
# #         print("\n")
# #         print(all_kg_results)
        
# #         print("\n")
# #         print("......reconstruction text............")
# #         print("\n")
# #         print(all_reconstruction_results)
#     except:
#         print(i)
#         pass

# %%
# df = pd.DataFrame({
#     'Input_Texts': input_string_so_far_list,
#     'Output_Graphs': all_kg_results,
#     'Output_Reconstructions': all_reconstruction_results, })


# print(df)

# # print("500 word sample evalution:", "\n")
# # base_cap_500, original_cap_500, knowledgegraph_cap_500, reconstruction_cap_500,QA_df = evaluate_peformance(df, 2,
# #                                                                                                      "q_a_kg.parquet")

# # print("No context correct answer percentage:", base_cap_500, "\n")
# # print("Original context correct answer percentage:", original_cap_500, "\n")
# # print("Knowledgegraph context correct answer percentage:", knowledgegraph_cap_500, "\n")
# # print("Reconstruckted text context correct answer percentage:", reconstruction_cap_500, "\n")

# %%
# df.to_csv("data/df_save_2500.csv", encoding='utf-8', index=False)
# #QA_df.to_csv("data/questions_answer_save_200.csv", encoding='utf-8', index=False)

# %%
#1000 paper for cot: 

# No context correct answer percentage: 44.19784400760939 

# Original context correct answer percentage: 84.14647730437204 

# Knowledgegraph context correct answer percentage: 77.47158824081902 

# Reconstruckted text context correct answer percentage: 77.27733804656881
